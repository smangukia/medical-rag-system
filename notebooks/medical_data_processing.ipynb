# %%
# !pip install -q sentence-transformers boto3 pandas numpy scikit-learn

# %%
import json
import boto3
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
import pickle
from sklearn.metrics.pairwise import cosine_similarity

s3 = boto3.client('s3')
bucket_name = 'medical-rag-data-b01015847' 

print("Environment setup complete!")
# Out:
# Environment setup complete!

# %% [markdown]
# ## Loading the Data Function

# %%
def load_medical_data_from_s3():
    """Load all JSON files from S3 and create structured chunks"""
    
    print("loading medical data from S3...")
    
    response = s3.list_objects_v2(
        Bucket=bucket_name,
        Prefix='raw-data/'
    )
    
    documents = []
    file_count = 0
    
    if 'Contents' not in response:
        print("no files found in raw-data folder!")
        return documents
    
    for obj in response['Contents']:
        if obj['Key'].endswith('.json'):
            try:
                file_response = s3.get_object(Bucket=bucket_name, Key=obj['Key'])
                data = json.loads(file_response['Body'].read().decode('utf-8'))
                
                articles_to_process = []
                
                if isinstance(data, list):
                    articles_to_process = data
                    print(f"Found list with {len(data)} articles in {obj['Key']}")
                elif isinstance(data, dict) and 'name' in data:
                    articles_to_process = [data]
                else:
                    print(f"Skipping {obj['Key']} - unknown format")
                    continue
                
                for article_data in articles_to_process:
                    if not isinstance(article_data, dict):
                        continue
                        
                    filename = obj['Key'].split('/')[-1].replace('.json', '')
                    doc_id = article_data.get('name', filename).replace(' ', '_').lower()
                    
                    sections = ['overview', 'symptoms', 'causes', 'diagnosis', 
                               'treatment', 'prognosis', 'prevention', 'complications']
                    
                    for section in sections:
                        if section in article_data and article_data[section] and str(article_data[section]).strip():
                            chunk = {
                                'doc_id': doc_id,
                                'section': section,
                                'content': str(article_data[section]).strip(),
                                'url': article_data.get('url', ''),
                                'title': article_data.get('name', filename),
                                'chunk_id': f"{doc_id}_{section}"
                            }
                            documents.append(chunk)
                    
                    combined_content = ' '.join([
                        str(article_data.get(s, '')) for s in sections 
                        if article_data.get(s) and str(article_data.get(s)).strip()
                    ])
                    
                    if combined_content.strip():
                        documents.append({
                            'doc_id': doc_id,
                            'section': 'full_article',
                            'content': combined_content.strip(),
                            'url': article_data.get('url', ''),
                            'title': article_data.get('name', filename),
                            'chunk_id': f"{doc_id}_full"
                        })
                    
                    file_count += 1
                    if file_count % 500 == 0:
                        print(f"Processed {file_count} articles...")
                        
            except Exception as e:
                print(f"Error processing {obj['Key']}: {str(e)}")
                continue
    
    print(f" Loaded {file_count} articles, created {len(documents)} chunks")
    return documents

medical_documents = load_medical_data_from_s3()
# Out:
# loading medical data from S3...
# Found list with 4203 articles in raw-data/all_articles.json
# Processed 500 articles...
# Processed 1000 articles...
# Processed 1500 articles...
# Processed 2000 articles...
# Processed 2500 articles...
# Processed 3000 articles...
# Processed 3500 articles...
# Processed 4000 articles...
# Processed 4500 articles...
# Processed 5000 articles...
#  Loaded 5201 articles, created 24910 chunks

# %%
if medical_documents:
    print(f" Data Analysis:")
    print(f"Total chunks: {len(medical_documents)}")
    
    section_counts = {}
    for doc in medical_documents:
        section = doc['section']
        section_counts[section] = section_counts.get(section, 0) + 1
    
    print(f"\nChunks by section:")
    for section, count in sorted(section_counts.items()):
        print(f"  {section}: {count}")

    print(f"\n Sample document chunk:")
    sample = medical_documents[0]
    print(f"Title: {sample['title']}")
    print(f"Section: {sample['section']}")
    print(f"Content preview: {sample['content'][:200]}...")
    
else:
    print(" No documents loaded!")
# Out:
#  Data Analysis:
# Total chunks: 24910
#
# Chunks by section:
#   causes: 3144
#   complications: 2564
#   diagnosis: 2020
#   full_article: 5178
#   overview: 4604
#   prevention: 913
#   symptoms: 2818
#   treatment: 3669
#
#  Sample document chunk:
# Title: A1C test
# Section: overview
# Content preview: A1C is a lab test that shows the average level of blood sugar (glucose) over the previous 3 months. It shows how well you are controlling your blood sugar to help prevent complications from diabetes....

# %% [markdown]
# ## Checking S3 contents

# %%
response = s3.list_objects_v2(Bucket=bucket_name, Prefix='raw-data/')

json_files = []
for obj in response['Contents']:
    if obj['Key'].endswith('.json'):
        json_files.append({
            'filename': obj['Key'],
            'size': obj['Size']
        })

print(f" Files in S3 bucket:")
print(f"Total JSON files: {len(json_files)}")

json_files_sorted = sorted(json_files, key=lambda x: x['size'], reverse=True)

print(f"\n Largest files (likely the combined file):")
for file in json_files_sorted[:5]:
    size_mb = file['size'] / (1024 * 1024)
    print(f"  {file['filename']}: {size_mb:.2f} MB")

print(f"\n First 10 files:")
for file in json_files[:10]:
    print(f"  {file['filename']}")
# Out:
#  Files in S3 bucket:
# Total JSON files: 999
#
#  Largest files (likely the combined file):
#   raw-data/all_articles.json: 6.34 MB
#   raw-data/congenital_heart_defect_-_corrective_surgery.json: 0.01 MB
#   raw-data/aging_changes_in_the_heart_and_blood_vessels.json: 0.01 MB
#   raw-data/covid-19_vaccine_-_what_you_need_to_know.json: 0.01 MB
#   raw-data/communicating_with_patients.json: 0.01 MB
#
#  First 10 files:
#   raw-data/a1c_test.json
#   raw-data/a_guide_to_clinical_trials_for_cancer.json
#   raw-data/a_guide_to_help_children_understand_cancer.json
#   raw-data/a_guide_to_herbal_remedies.json
#   raw-data/aarskog_syndrome.json
#   raw-data/aase_syndrome.json
#   raw-data/abdomen_-_swollen.json
#   raw-data/abdominal_aortic_aneurysm.json
#   raw-data/abdominal_aortic_aneurysm_repair_-_open.json
#   raw-data/abdominal_aortic_aneurysm_repair_-_open_-_discharge.json

# %% [markdown]
# ## Loading Clean Data

# %%
def load_from_combined_file_only():
    """Load only from the combined all_articles.json file"""
    
    print("Loading from combined file only...")
    
    try:
        file_response = s3.get_object(Bucket=bucket_name, Key='raw-data/all_articles.json')
        articles_list = json.loads(file_response['Body'].read().decode('utf-8'))
        
        print(f"Found {len(articles_list)} articles in combined file")
        
        documents = []
        
        for i, article_data in enumerate(articles_list):
            if not isinstance(article_data, dict):
                continue

            doc_id = article_data.get('name', f'article_{i}').replace(' ', '_').lower()

            sections = ['overview', 'symptoms', 'causes', 'diagnosis', 
                       'treatment', 'prognosis', 'prevention', 'complications']
            
            for section in sections:
                if section in article_data and article_data[section] and str(article_data[section]).strip():
                    chunk = {
                        'doc_id': doc_id,
                        'section': section,
                        'content': str(article_data[section]).strip(),
                        'url': article_data.get('url', ''),
                        'title': article_data.get('name', f'Article {i}'),
                        'chunk_id': f"{doc_id}_{section}"
                    }
                    documents.append(chunk)
            
            if (i + 1) % 1000 == 0:
                print(f"Processed {i + 1} articles...")
        
        print(f"Created {len(documents)} chunks from {len(articles_list)} articles")
        return documents
        
    except Exception as e:
        print(f"Error: {str(e)}")
        return []

medical_documents_clean = load_from_combined_file_only()
# Out:
# Loading from combined file only...
# Found 4203 articles in combined file
# Processed 1000 articles...
# Processed 2000 articles...
# Processed 3000 articles...
# Processed 4000 articles...
# Created 15906 chunks from 4203 articles

# %% [markdown]
# ## Analyzing Clean Data

# %%
if medical_documents_clean:
    print(f"Clean Data Analysis:")
    print(f"Total articles: 4203")
    print(f"Total chunks: {len(medical_documents_clean)}")
    print(f"Average chunks per article: {len(medical_documents_clean)/4203:.1f}")
    
    section_counts = {}
    for doc in medical_documents_clean:
        section = doc['section']
        section_counts[section] = section_counts.get(section, 0) + 1
    
    print(f"\n Chunks by section:")
    for section, count in sorted(section_counts.items()):
        print(f"  {section}: {count:,}")
    
    print(f"\n Sample document chunk:")
    sample = medical_documents_clean[0]
    print(f"Title: {sample['title']}")
    print(f"Section: {sample['section']}")
    print(f"Content length: {len(sample['content'])} characters")
    print(f"Content preview: {sample['content'][:200]}...")
    
    processed_data = json.dumps(medical_documents_clean, indent=2)
    s3.put_object(
        Bucket='medical-rag-processed-b01015847', 
        Key='processed_chunks.json',
        Body=processed_data
    )
    print(f"\n Saved processed chunks to S3!")
    
else:
    print(" No clean documents loaded!")
# Out:
# Clean Data Analysis:
# Total articles: 4203
# Total chunks: 15906
# Average chunks per article: 3.8
#
#  Chunks by section:
#   causes: 2,537
#   complications: 2,063
#   diagnosis: 1,632
#   overview: 3,700
#   prevention: 736
#   symptoms: 2,282
#   treatment: 2,956
#
#  Sample document chunk:
# Title: A guide to clinical trials for cancer
# Section: overview
# Content length: 348 characters
# Content preview: If you havecancer, a clinical trial may be an option for managing your cancer. A clinical trial is a study using people who agree to participate in new tests or treatments. Clinical trials help resear...
#
#  Saved processed chunks to S3!

# %% [markdown]
# ## Generating Embeddings

# %%
print("Loading embedding model...")
model = SentenceTransformer('all-MiniLM-L6-v2')
print("Model loaded successfully!")

def generate_embeddings_batch(documents, batch_size=100):
    """Generate embeddings for documents in batches"""
    
    print(f"Generating embeddings for {len(documents)} chunks...")
    
    embeddings_data = []
    
    for i in range(0, len(documents), batch_size):
        batch = documents[i:i + batch_size]
        
        batch_content = [doc['content'] for doc in batch]

        batch_embeddings = model.encode(batch_content, show_progress_bar=False)
        
        for j, doc in enumerate(batch):
            embedding_record = {
                'chunk_id': doc['chunk_id'],
                'doc_id': doc['doc_id'],
                'section': doc['section'],
                'title': doc['title'],
                'content': doc['content'],
                'url': doc['url'],
                'embedding': batch_embeddings[j].tolist() 
            }
            embeddings_data.append(embedding_record)

        processed = min(i + batch_size, len(documents))
        if processed % 1000 == 0 or processed == len(documents):
            print(f"  Generated embeddings for {processed:,}/{len(documents):,} chunks")
    
    return embeddings_data

embeddings_data = generate_embeddings_batch(medical_documents_clean)

print(f" Generated {len(embeddings_data)} embeddings")
print(f" Embedding dimension: {len(embeddings_data[0]['embedding'])}")
# Out:
# Loading embedding model...
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Model loaded successfully!
# Generating embeddings for 15906 chunks...
#   Generated embeddings for 1,000/15,906 chunks
#   Generated embeddings for 2,000/15,906 chunks
#   Generated embeddings for 3,000/15,906 chunks
#   Generated embeddings for 4,000/15,906 chunks
#   Generated embeddings for 5,000/15,906 chunks
#   Generated embeddings for 6,000/15,906 chunks
#   Generated embeddings for 7,000/15,906 chunks
#   Generated embeddings for 8,000/15,906 chunks
#   Generated embeddings for 9,000/15,906 chunks
#   Generated embeddings for 10,000/15,906 chunks
#   Generated embeddings for 11,000/15,906 chunks
#   Generated embeddings for 12,000/15,906 chunks
#   Generated embeddings for 13,000/15,906 chunks
#   Generated embeddings for 14,000/15,906 chunks
#   Generated embeddings for 15,000/15,906 chunks
#   Generated embeddings for 15,906/15,906 chunks
#  Generated 15906 embeddings
#  Embedding dimension: 384

# %% [markdown]
# ## Saving embeddings and creating search function

# %%
print("Saving embeddings to S3...")

embeddings_json = json.dumps(embeddings_data, indent=2)
s3.put_object(
    Bucket='medical-rag-processed-b01015847',
    Key='medical_embeddings.json',
    Body=embeddings_json
)

import pickle
with open('/tmp/embeddings.pkl', 'wb') as f:
    pickle.dump(embeddings_data, f)

s3.upload_file('/tmp/embeddings.pkl', 'medical-rag-processed-b01015847', 'medical_embeddings.pkl')

print("Embeddings saved to S3!")

def search_medical_information(query, top_k=5):
    """Search for relevant medical information using semantic similarity"""
    
    print(f"Searching for: '{query}'")

    query_embedding = model.encode([query])[0]
    
    similarities = []
    
    for i, embedding_record in enumerate(embeddings_data):
        chunk_embedding = np.array(embedding_record['embedding'])
        similarity = cosine_similarity([query_embedding], [chunk_embedding])[0][0]
        
        similarities.append({
            'score': similarity,
            'title': embedding_record['title'],
            'section': embedding_record['section'],
            'content': embedding_record['content'],
            'url': embedding_record['url']
        })
    
    similarities.sort(key=lambda x: x['score'], reverse=True)
    
    return similarities[:top_k]

print("Search function is ready")
# Out:
# Saving embeddings to S3...
# Embeddings saved to S3!
# Search function is ready

# %% [markdown]
# ## Testing the RAG System

# %%
test_queries = [
    "What are the symptoms of diabetes?",
    "How to treat high blood pressure?",
    "What causes heart disease?",
    "Chest pain symptoms",
    "How to prevent stroke?"
]

print("Testing Medical RAG System")
print("=" * 50)

for query in test_queries:
    print(f"\nQuery: {query}")
    print("-" * 40)
    
    results = search_medical_information(query, top_k=3)
    
    for i, result in enumerate(results, 1):
        print(f"\n{i}. {result['title']} ({result['section']})")
        print(f"   Relevance: {result['score']:.3f}")
        print(f"   Content: {result['content'][:150]}...")
        if result['url']:
            print(f"   Source: {result['url']}")
    
    print("\n" + "="*50)
# Out:
# Testing Medical RAG System
# ==================================================
#
# Query: What are the symptoms of diabetes?
# ----------------------------------------
# Searching for: 'What are the symptoms of diabetes?'
#
# 1. Managing your blood sugar (symptoms)
#    Relevance: 0.685
#    Content: Symptoms of this condition include:
#
# • The time of day
# • Your blood sugar level
# • The amount of carbohydrates you ate
# • The type and dose of your diab...
#    Source: https://medlineplus.gov/ency/patientinstructions/000086.htm
#
# 2. Diabetes (symptoms)
#    Relevance: 0.656
#    Content: Symptoms of this condition include:
#
# • Blurry vision
# • Excess thirst
# • Fatigue
# • Frequent urination
# • Hunger
# • Weight loss...
#    Source: https://medlineplus.gov/ency/article/001214.htm
#
# 3. Type 2 diabetes - self-care (symptoms)
#    Relevance: 0.647
#    Content: Symptoms of this condition include:
#
# • Hunger
# • Thirst
# • Urinating a lot, getting up more often than usual at night to urinate
# • Blurry vision
# • More ...
#    Source: https://medlineplus.gov/ency/patientinstructions/000328.htm
#
# ==================================================
#
# Query: How to treat high blood pressure?
# ----------------------------------------
# Searching for: 'How to treat high blood pressure?'
#
# 1. Atherosclerosis (treatment)
#    Relevance: 0.705
#    Content: Treatment options include:
#
# • Do not stop or change high blood pressure medicines without talking to your provider....
#    Source: https://medlineplus.gov/ency/article/000171.htm
#
# 2. Polycystic kidney disease (treatment)
#    Relevance: 0.691
#    Content: Treatment options include:
#
# • Blood pressure medicines
# • Diuretics (water pills)
# • Low-salt diet...
#    Source: https://medlineplus.gov/ency/article/000502.htm
#
# 3. Abdominal aortic aneurysm repair - open - discharge (treatment)
#    Relevance: 0.633
#    Content: Treatment options include:
#
# • Eat a heart-healthy diet.
# • Get regular exercise.
# • Stop smoking (if you smoke).
# • Take the medicines your health care p...
#    Source: https://medlineplus.gov/ency/patientinstructions/000240.htm
#
# ==================================================
#
# Query: What causes heart disease?
# ----------------------------------------
# Searching for: 'What causes heart disease?'
#
# 1. Heart failure in children (causes)
#    Relevance: 0.760
#    Content: Causes of this condition include:
#
# • Infection from a virus or bacteria that causes damage to the heart muscle or heart valves
# • Drugs used for other ...
#    Source: https://medlineplus.gov/ency/article/007698.htm
#
# 2. Coronary artery fistula (causes)
#    Relevance: 0.726
#    Content: Causes of this condition include:
#
# • An infection that weakens the wall of the coronary artery and the heart
# • Certain types of heart surgery
# • Injury...
#    Source: https://medlineplus.gov/ency/article/007315.htm
#
# 3. Cholesterol and lifestyle (causes)
#    Relevance: 0.720
#    Content: Causes of this condition include:
#
# • Heart attack
# • Stroke
# • Serious heart or blood vessel disease...
#    Source: https://medlineplus.gov/ency/patientinstructions/000099.htm
#
# ==================================================
#
# Query: Chest pain symptoms
# ----------------------------------------
# Searching for: 'Chest pain symptoms'
#
# 1. Myristica oil poisoning (symptoms)
#    Relevance: 0.858
#    Content: Symptoms of this condition include:
#
# • Chest pain...
#    Source: https://medlineplus.gov/ency/article/002899.htm
#
# 2. Costochondritis (symptoms)
#    Relevance: 0.769
#    Content: Symptoms of this condition include:
#
# • Sharp pain at the front of your chest wall, which may move to your back or stomach
# • Increased pain when you ta...
#    Source: https://medlineplus.gov/ency/article/000164.htm
#
# 3. Pericarditis - after heart attack (symptoms)
#    Relevance: 0.757
#    Content: Symptoms of this condition include:
#
# • Anxiety
# • Chest painfrom the swollen pericardium rubbing on the heart. The pain may be sharp, tight or crushing...
#    Source: https://medlineplus.gov/ency/article/000166.htm
#
# ==================================================
#
# Query: How to prevent stroke?
# ----------------------------------------
# Searching for: 'How to prevent stroke?'
#
# 1. Stroke risk factors (prevention)
#    Relevance: 0.650
#    Content: stroke; stroke - prevention; cva - prevention; tia - prevention...
#    Source: https://medlineplus.gov/ency/patientinstructions/000341.htm
#
# 2. Carotid artery stenosis - self-care (treatment)
#    Relevance: 0.640
#    Content: Treatment options include:
#
# • Prevent further narrowing of these important arteries
# • Prevent a stroke from occurring...
#    Source: https://medlineplus.gov/ency/patientinstructions/000717.htm
#
# 3. Stroke (treatment)
#    Relevance: 0.624
#    Content: Treatment options include:
#
# • Check for problems with vision, movement, feeling, reflexes, understanding, and speaking. Your provider and nurses will ...
#    Source: https://medlineplus.gov/ency/article/000726.htm
#
# ==================================================

# %% [markdown]
# ## Interactive search function

# %%
def interactive_medical_search():
    """Interactive search function for testing"""
    
    print("Medical Information RAG System")
    print("Ask questions about medical conditions, symptoms, treatments, etc.")
    print("Type 'quit' to exit")
    print("-" * 50)
    
    while True:
        user_query = input("\nEnter your medical question: ").strip()
        
        if user_query.lower() in ['quit', 'exit', 'q']:
            print("Thank you for using the Medical RAG System!")
            break
        
        if not user_query:
            print("Please enter a valid question.")
            continue
        
        try:
            results = search_medical_information(user_query, top_k=3)
            
            print(f"\nResults for: '{user_query}'")
            print("-" * 40)
            
            for i, result in enumerate(results, 1):
                print(f"\n{i}.{result['title']}")
                print(f" Section: {result['section']}")
                print(f" Relevance: {result['score']:.3f}")
                print(f" Content: {result['content'][:200]}...")
                if result['url']:
                    print(f" Source: {result['url']}")
            
        except Exception as e:
            print(f"Error: {str(e)}")

# uncomment the line below to start interactive mode
interactive_medical_search()
# Out:
# Medical Information RAG System
# Ask questions about medical conditions, symptoms, treatments, etc.
# Type 'quit' to exit
# --------------------------------------------------
# Enter your medical question:  quit
# Thank you for using the Medical RAG System!

# %% [markdown]
# ## System performance analysis

# %%
import time

def analyze_system_performance():
    """Analyze search performance and accuracy"""
    
    print("System Performance Analysis")
    print("=" * 40)
    
    test_query = "diabetes symptoms treatment"
    
    start_time = time.time()
    results = search_medical_information(test_query, top_k=5)
    search_time = time.time() - start_time
    
    print(f"Search Speed:")
    print(f" Query: '{test_query}'")
    print(f" Time: {search_time:.3f} seconds")
    print(f" Chunks searched: {len(embeddings_data):,}")
    print(f" Speed: {len(embeddings_data)/search_time:.0f} chunks/second")
    
    print(f"\nResult Quality:")
    for i, result in enumerate(results[:3], 1):
        print(f"   {i}. {result['title']} - Score: {result['score']:.3f}")
    
    print(f"\nSystem Statistics:")
    print(f" Total medical articles: 4,203")
    print(f" Total searchable chunks: {len(embeddings_data):,}")
    print(f" Embedding dimensions: 384")
    print(f" Model: all-MiniLM-L6-v2")
    print(f" Average search time: ~{search_time:.3f} seconds")

analyze_system_performance()
# Out:
# System Performance Analysis
# ========================================
# Searching for: 'diabetes symptoms treatment'
# Search Speed:
#  Query: 'diabetes symptoms treatment'
#  Time: 8.142 seconds
#  Chunks searched: 15,906
#  Speed: 1954 chunks/second
#
# Result Quality:
#    1. Drug-induced low blood sugar - Score: 0.632
#    2. Hypothalamus - Score: 0.623
#    3. Type 1 diabetes - Score: 0.618
#
# System Statistics:
#  Total medical articles: 4,203
#  Total searchable chunks: 15,906
#  Embedding dimensions: 384
#  Model: all-MiniLM-L6-v2
#  Average search time: ~8.142 seconds

# %% [markdown]
# ## Uploading embeddings to DynamoDB

# %%
import boto3
from decimal import Decimal
import json

dynamodb = boto3.resource('dynamodb')
embeddings_table = dynamodb.Table('MedicalEmbeddings')

def deduplicate_embeddings(embeddings_data):
    """Remove duplicate chunk_ids from embeddings data"""
    
    print("Checking for duplicates...")
    
    seen_chunk_ids = set()
    deduplicated_data = []
    duplicates_found = 0
    
    for embedding_record in embeddings_data:
        chunk_id = embedding_record['chunk_id']
        
        if chunk_id not in seen_chunk_ids:
            seen_chunk_ids.add(chunk_id)
            deduplicated_data.append(embedding_record)
        else:
            duplicates_found += 1
    
    print(f"Original: {len(embeddings_data):,} items")
    print(f"Duplicates removed: {duplicates_found:,}")
    print(f"Final unique items: {len(deduplicated_data):,}")
    
    return deduplicated_data

def upload_embeddings_to_dynamodb(embeddings_data, batch_size=20):
    """Upload embeddings to DynamoDB in smaller batches"""
    
    clean_data = deduplicate_embeddings(embeddings_data)
    
    print(f"Uploading {len(clean_data)} unique embeddings to DynamoDB...")
    
    success_count = 0
    error_count = 0
    
    for i in range(0, len(clean_data), batch_size):
        try:
            batch = clean_data[i:i + batch_size]
            
            with embeddings_table.batch_writer() as batch_writer:
                for embedding_record in batch:
                    embedding_list = [Decimal(str(float(x))) for x in embedding_record['embedding']]
                    
                    item = {
                        'chunk_id': embedding_record['chunk_id'],
                        'doc_id': embedding_record['doc_id'],
                        'section': embedding_record['section'],
                        'title': embedding_record['title'],
                        'content': embedding_record['content'][:4000],
                        'url': embedding_record['url'],
                        'embedding': embedding_list
                    }
                    
                    batch_writer.put_item(Item=item)
            
            success_count += len(batch)

            if success_count % 1000 == 0 or success_count >= len(clean_data):
                print(f" Uploaded {success_count:,}/{len(clean_data):,} embeddings")
                
        except Exception as e:
            error_count += len(batch)
            print(f" Error in batch {i//batch_size + 1}: {str(e)}")
            continue
    
    print(f"Upload complete! Success: {success_count:,}, Errors: {error_count}")
    return success_count

success_count = upload_embeddings_to_dynamodb(embeddings_data)
# Out:
# Checking for duplicates...
# Original: 15,906 items
# Duplicates removed: 6
# Final unique items: 15,900
# Uploading 15900 unique embeddings to DynamoDB...
#  Uploaded 1,000/15,900 embeddings
#  Uploaded 2,000/15,900 embeddings
#  Uploaded 3,000/15,900 embeddings
#  Uploaded 4,000/15,900 embeddings
#  Uploaded 5,000/15,900 embeddings
#  Uploaded 6,000/15,900 embeddings
#  Uploaded 7,000/15,900 embeddings
#  Uploaded 8,000/15,900 embeddings
#  Uploaded 9,000/15,900 embeddings
#  Uploaded 10,000/15,900 embeddings
#  Uploaded 11,000/15,900 embeddings
#  Uploaded 12,000/15,900 embeddings
#  Uploaded 13,000/15,900 embeddings
#  Uploaded 14,000/15,900 embeddings
#  Uploaded 15,000/15,900 embeddings
#  Uploaded 15,900/15,900 embeddings
# Upload complete! Success: 15,900, Errors: 0

# %% [markdown]
# ## Verifying upload and testing retrieval

# %%
import time

def verify_dynamodb_upload():
    """Verifying embeddings are properly stored in DynamoDB"""
    
    print("Verifying DynamoDB Upload:")
    
    dynamodb_client = boto3.client('dynamodb')
    response = dynamodb_client.describe_table(TableName='MedicalEmbeddings')
    print(f"   Table status: {response['Table']['TableStatus']}")
    
    sample_chunk_id = embeddings_data[0]['chunk_id']
    response = embeddings_table.get_item(Key={'chunk_id': sample_chunk_id})
    
    if 'Item' in response:
        item = response['Item']
        print(f"Sample retrieval successful:")
        print(f"   Title: {item['title']}")
        print(f"   Section: {item['section']}")
        print(f"   Content length: {len(item['content'])} chars")
        print(f"   Embedding dimensions: {len(item['embedding'])}")
        print(f"   URL: {item['url']}")
        
        return True
    else:
        print("Sample retrieval failed")
        return False

def create_dynamodb_search_function():
    """Creating search function that uses DynamoDB instead of memory"""
    
    def search_medical_information_dynamodb(query, top_k=5):
        """Search using DynamoDB stored embeddings"""
        
        print(f"Searching DynamoDB for: '{query}'")
        start_time = time.time()
        
        query_embedding = model.encode([query])[0]
 
        print(" Scanning DynamoDB table...")
        response = embeddings_table.scan()
        items = response['Items']
        
        while 'LastEvaluatedKey' in response:
            response = embeddings_table.scan(ExclusiveStartKey=response['LastEvaluatedKey'])
            items.extend(response['Items'])
        
        print(f" Retrieved {len(items):,} items from DynamoDB")
        
        similarities = []
        for item in items:
            item_embedding = [float(x) for x in item['embedding']]
            
            similarity = cosine_similarity([query_embedding], [item_embedding])[0][0]
            
            similarities.append({
                'score': similarity,
                'title': item['title'],
                'section': item['section'],
                'content': item['content'],
                'url': item['url']
            })
        
        similarities.sort(key=lambda x: x['score'], reverse=True)
        
        search_time = time.time() - start_time
        print(f" Search completed in {search_time:.2f} seconds")
        
        return similarities[:top_k]
    
    return search_medical_information_dynamodb

verify_success = verify_dynamodb_upload()

if verify_success:
    search_dynamodb = create_dynamodb_search_function()
    print("\nDynamoDB search function ready!")
else:
    print("\nUpload verification failed!")
# Out:
# Verifying DynamoDB Upload:
#    Table status: ACTIVE
# Sample retrieval successful:
#    Title: A guide to clinical trials for cancer
#    Section: overview
#    Content length: 348 chars
#    Embedding dimensions: 384
#    URL: https://medlineplus.gov/ency/patientinstructions/000823.htm
#
# DynamoDB search function ready!

# %%
if verify_success:
    print("Testing DynamoDB Search System")
    print("=" * 50)
    
    test_query = "diabetes treatment options"
    results = search_dynamodb(test_query, top_k=3)
    
    print(f"\nResults for: '{test_query}'")
    print("-" * 40)
    
    for i, result in enumerate(results, 1):
        print(f"\n{i}. {result['title']} ({result['section']})")
        print(f"   Relevance: {result['score']:.3f}")
        print(f"   Content: {result['content'][:150]}...")
        if result['url']:
            print(f"   Source: {result['url']}")
    
    print(f"\nDynamoDB vector database is working perfectly!")
    
else:
    print("Cannot test - upload verification failed")
# Out:
# Testing DynamoDB Search System
# ==================================================
# Searching DynamoDB for: 'diabetes treatment options'
#  Scanning DynamoDB table...
#  Retrieved 15,900 items from DynamoDB
#  Search completed in 57.49 seconds
#
# Results for: 'diabetes treatment options'
# ----------------------------------------
#
# 1. Diabetes tests and checkups (treatment)
#    Relevance: 0.786
#    Content: Treatment options include:
#
# • Ask your health care provider questions
# • Learn more about your diabetes and what you can do to keep your blood sugar in...
#    Source: https://medlineplus.gov/ency/patientinstructions/000082.htm
#
# 2. Weight-loss surgery and children (treatment)
#    Relevance: 0.747
#    Content: Treatment options include:
#
# • Better control of diabetes
# • Lower cholesterol and blood pressure
# • Fewer sleep problems...
#    Source: https://medlineplus.gov/ency/patientinstructions/000356.htm
#
# 3. Drug-induced low blood sugar (treatment)
#    Relevance: 0.742
#    Content: Treatment options include:
#
# • Drinking alcohol
# • Getting more activity than usual
# • Intentionally or unintentionally overdosing on the medicines used ...
#    Source: https://medlineplus.gov/ency/article/000310.htm
#
# DynamoDB vector database is working perfectly!

# %% [markdown]
# ## Installing and loading hugging face model

# %%
# !pip install -q transformers torch

from transformers import pipeline, AutoTokenizer, AutoModelForSeq2SeqLM
import torch

print("Loading Hugging Face model for text generation...")

try:
    summarizer = pipeline(
        "summarization", 
        model="facebook/bart-large-cnn",
        device=0 if torch.cuda.is_available() else -1
    )
    print("BART summarization model loaded successfully!")
    
except Exception as e:
    print(f" Error loading BART: {e}")
    
    try:
        summarizer = pipeline(
            "summarization",
            model="sshleifer/distilbart-cnn-12-6",
            device=-1  # CPU only
        )
        print("DistilBART model loaded successfully!")
    except Exception as e2:
        print(f"Error loading fallback model: {e2}")
        summarizer = None

if summarizer:
    test_text = "Diabetes is a group of metabolic disorders characterized by high blood sugar levels over a prolonged period."
    test_summary = summarizer(test_text, max_length=50, min_length=20)
    print(f"Test summary: {test_summary[0]['summary_text']}")
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Loading Hugging Face model for text generation...
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu
# Your max_length is set to 50, but your input_length is only 20. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=10)
# BART summarization model loaded successfully!
# Test summary: Diabetes is a group of metabolic disorders characterized by high blood sugar levels over a prolonged period.

# %% [markdown]
# ## Enhanced medical RAG with LLM

# %%
def enhanced_medical_search_with_llm(query, top_k=3):
    """Enhanced search that combines retrieval with LLM generation"""
    
    print(f"Enhanced search for: '{query}'")
    
    if 'search_dynamodb' in globals():
        retrieved_results = search_dynamodb(query, top_k=top_k)
    else:
        retrieved_results = search_medical_information(query, top_k=top_k)
    
    if not retrieved_results or not summarizer:
        return {
            'query': query,
            'retrieved_results': retrieved_results,
            'generated_response': "LLM not available, showing retrieved results only.",
            'method': 'retrieval_only'
        }
    
    combined_content = ""
    sources = []
    
    for result in retrieved_results:
        combined_content += f"\n{result['title']} ({result['section']}):\n{result['content'][:300]}...\n"
        sources.append({
            'title': result['title'],
            'section': result['section'],
            'url': result.get('url', ''),
            'relevance': result.get('score', 0)
        })

    try:
        medical_prompt = f"""Medical Question: {query}

Relevant Medical Information:
{combined_content}

Please provide a clear, accurate summary based on the medical information provided above."""
        
        if len(medical_prompt) > 1000:
            medical_prompt = medical_prompt[:1000] + "..."
        
        generated = summarizer(
            medical_prompt,
            max_length=200,
            min_length=50,
            do_sample=False
        )
        
        generated_response = generated[0]['summary_text']
        
    except Exception as e:
        print(f"LLM generation failed: {e}")
        generated_response = f"Based on medical sources: {retrieved_results[0]['content'][:200]}..."
    
    return {
        'query': query,
        'generated_response': generated_response,
        'retrieved_results': retrieved_results,
        'sources': sources,
        'method': 'retrieval_plus_generation',
        'timestamp': time.time()
    }

print("Enhanced Medical RAG with LLM ready!")
# Out:
# Enhanced Medical RAG with LLM ready!

# %% [markdown]
# ## Testing Enhanced medical RAG system

# %%
test_queries = [
    "What are the symptoms of diabetes?",
    "How to treat high blood pressure?", 
    "What causes heart disease?",
    "Chest pain symptoms and causes"
]

print("Testing Enhanced Medical RAG System with LLM")
print("=" * 60)

for query in test_queries:
    print(f"\nQuery: {query}")
    print("-" * 50)
    
    enhanced_result = enhanced_medical_search_with_llm(query, top_k=3)
    
    print(f"**Generated Response:**")
    print(f"{enhanced_result['generated_response']}")
    
    print(f"\n**Retrieved Sources:**")
    for i, source in enumerate(enhanced_result['sources'][:2], 1):
        print(f"   {i}. {source['title']} ({source['section']})")
        if 'relevance' in source:
            print(f"      Relevance: {source['relevance']:.3f}")
    
    print(f"\nMethod: {enhanced_result['method']}")
    print("\n" + "="*60)
# Out:
# Testing Enhanced Medical RAG System with LLM
# ============================================================
#
# Query: What are the symptoms of diabetes?
# --------------------------------------------------
# Enhanced search for: 'What are the symptoms of diabetes?'
# Searching DynamoDB for: 'What are the symptoms of diabetes?'
#  Scanning DynamoDB table...
#  Retrieved 15,900 items from DynamoDB
#  Search completed in 57.14 seconds
# **Generated Response:**
# Diabetes (symptoms) includes: Urinating a lot, getting up more often than usual at night to urinate, blurry vision and weight loss. Diabetes self-care includes: Hunger, Fatigue, Urination, Blurry vision, Red skin rashes and Tinglin.
#
# **Retrieved Sources:**
#    1. Managing your blood sugar (symptoms)
#       Relevance: 0.685
#    2. Diabetes (symptoms)
#       Relevance: 0.656
#
# Method: retrieval_plus_generation
#
# ============================================================
#
# Query: How to treat high blood pressure?
# --------------------------------------------------
# Enhanced search for: 'How to treat high blood pressure?'
# Searching DynamoDB for: 'How to treat high blood pressure?'
#  Scanning DynamoDB table...
#  Retrieved 15,900 items from DynamoDB
# Your max_length is set to 200, but your input_length is only 189. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=94)
#  Search completed in 55.17 seconds
# **Generated Response:**
# Please provide a clear, accurate summary based on the medical information provided above. Medical Question: How to treat high blood pressure? How do you get low-salt diet? What are your treatment options for polycystic kidney disease? What is your treatment for the aneurysm?
#
# **Retrieved Sources:**
#    1. Atherosclerosis (treatment)
#       Relevance: 0.705
#    2. Polycystic kidney disease (treatment)
#       Relevance: 0.691
#
# Method: retrieval_plus_generation
#
# ============================================================
#
# Query: What causes heart disease?
# --------------------------------------------------
# Enhanced search for: 'What causes heart disease?'
# Searching DynamoDB for: 'What causes heart disease?'
#  Scanning DynamoDB table...
#  Retrieved 15,900 items from DynamoDB
#  Search completed in 54.74 seconds
# **Generated Response:**
# Heart failure in children (causes): Infection from a virus or bacteria that causes damage to the heart muscle or heart valves. Drugs used for other illnesses, most often cancer drugs. Abnormal heart rhythms. Muscle disorders, such as muscular dystrophy. Genetic disorders leading to abnormal dev...
#
# **Retrieved Sources:**
#    1. Heart failure in children (causes)
#       Relevance: 0.760
#    2. Coronary artery fistula (causes)
#       Relevance: 0.726
#
# Method: retrieval_plus_generation
#
# ============================================================
#
# Query: Chest pain symptoms and causes
# --------------------------------------------------
# Enhanced search for: 'Chest pain symptoms and causes'
# Searching DynamoDB for: 'Chest pain symptoms and causes'
#  Scanning DynamoDB table...
#  Retrieved 15,900 items from DynamoDB
#  Search completed in 56.46 seconds
# **Generated Response:**
# The most common symptom is chest pain that may feel like tightness, heavy pressure, squeezing, or crushing pain. The pain may spread to the arm, shoulder, jaw, or back. Causes of this condition include: Anginaor a heart attack. A tear in the wall of the aorta.
#
# **Retrieved Sources:**
#    1. Myristica oil poisoning (symptoms)
#       Relevance: 0.856
#    2. Costochondritis (symptoms)
#       Relevance: 0.759
#
# Method: retrieval_plus_generation
#
# ============================================================

# %% [markdown]
# ## Comparing systems

# %%
comparison_query = "diabetes treatment and management"

print("SYSTEM COMPARISON")
print("=" * 50)

print("Traditional Retrieval Results:")
traditional_results = search_medical_information(comparison_query, top_k=3)
for i, result in enumerate(traditional_results[:2], 1):
    print(f"{i}. {result['title']}: {result['content'][:100]}...")

print("\n" + "-"*50)

print("Enhanced with LLM:")
enhanced_result = enhanced_medical_search_with_llm(comparison_query, top_k=3)
print(f"Generated Response: {enhanced_result['generated_response']}")
# Out:
# SYSTEM COMPARISON
# ==================================================
# Traditional Retrieval Results:
# Searching for: 'diabetes treatment and management'
# 1. Diabetes tests and checkups: Treatment options include:
#
# • Ask your health care provider questions
# • Learn more about your diabet...
# 2. Drug-induced low blood sugar: Treatment options include:
#
# • Drinking alcohol
# • Getting more activity than usual
# • Intentionally or...
#
# --------------------------------------------------
# Enhanced with LLM:
# Enhanced search for: 'diabetes treatment and management'
# Searching DynamoDB for: 'diabetes treatment and management'
#  Scanning DynamoDB table...
#  Retrieved 15,900 items from DynamoDB
# Your max_length is set to 200, but your input_length is only 188. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=94)
#  Search completed in 56.06 seconds
# Generated Response: Please provide a clear, accurate summary based on the medical information provided above. Medical Question: diabetes treatment and management. Relevant Medical Information: diabetes tests and checkups (treatment), drug-induced low blood sugar (treatment) and managing blood sugar during exercise.

# %% [markdown]
# ## Improved LLM Prompting

# %%
def enhanced_medical_search_with_improved_llm(query, top_k=3):
    """Enhanced search with better LLM prompting"""
    
    print(f"Enhanced search for: '{query}'")
    
    if 'search_dynamodb' in globals():
        retrieved_results = search_dynamodb(query, top_k=top_k)
    else:
        retrieved_results = search_medical_information(query, top_k=top_k)
    
    if not retrieved_results or not summarizer:
        return {
            'query': query,
            'retrieved_results': retrieved_results,
            'generated_response': "Showing retrieved medical information.",
            'method': 'retrieval_only'
        }
    
    medical_facts = []
    sources = []
    
    for result in retrieved_results:
        content = result['content'].strip()
        if content:
            medical_facts.append(f"From {result['title']} ({result['section']}): {content[:200]}")
            sources.append({
                'title': result['title'],
                'section': result['section'],
                'url': result.get('url', ''),
                'relevance': result.get('score', 0)
            })
    
    try:
        combined_facts = "\n\n".join(medical_facts[:3])
        
        medical_content = f"""Medical information about {query}:

{combined_facts}

Based on this medical information, here are the key points:"""
        
        generated = summarizer(
            medical_content,
            max_length=min(150, len(medical_content.split()) + 50),
            min_length=30,
            do_sample=False,
            no_repeat_ngram_size=3
        )
        
        generated_response = generated[0]['summary_text']
        
        if generated_response.startswith("Medical information about"):
            generated_response = generated_response.split("Based on this medical information, here are the key points:")[-1].strip()
        
    except Exception as e:
        print(f"LLM generation failed: {e}")
        generated_response = f"According to {retrieved_results[0]['title']}: {retrieved_results[0]['content'][:150]}..."
    
    return {
        'query': query,
        'generated_response': generated_response,
        'retrieved_results': retrieved_results,
        'sources': sources,
        'method': 'enhanced_rag',
        'timestamp': time.time()
    }

print("Improved Medical RAG ready!")
# Out:
# Improved Medical RAG ready!

# %% [markdown]
# ## Testing improved system

# %%
test_query = "How to treat high blood pressure?"

print("Testing Improved Medical RAG")
print("=" * 50)

improved_result = enhanced_medical_search_with_improved_llm(test_query)

print(f"Query: {test_query}")
print(f"\nEnhanced Response:")
print(f"{improved_result['generated_response']}")

print(f"\nSources Used:")
for i, source in enumerate(improved_result['sources'], 1):
    print(f"   {i}. {source['title']} ({source['section']}) - Relevance: {source['relevance']:.3f}")
# Out:
# Testing Improved Medical RAG
# ==================================================
# Enhanced search for: 'How to treat high blood pressure?'
# Searching DynamoDB for: 'How to treat high blood pressure?'
#  Scanning DynamoDB table...
#  Retrieved 15,900 items from DynamoDB
#  Search completed in 54.21 seconds
# Query: How to treat high blood pressure?
#
# Enhanced Response:
# Do not stop or change high blood pressure medicines without talking to your provider. Eat a heart-healthy diet. Get regular exercise. Stop smoking (if you smoke).
#
# Sources Used:
#    1. Atherosclerosis (treatment) - Relevance: 0.705
#    2. Polycystic kidney disease (treatment) - Relevance: 0.691
#    3. Abdominal aortic aneurysm repair - open - discharge (treatment) - Relevance: 0.633

# %% [markdown]
# ## Test -Check available diabetes content

# %%
def find_diabetes_content():
    """Finding all diabetes-related content in database"""
    
    diabetes_content = []
    
    for doc in medical_documents_clean:
        title = doc['title'].lower()
        content = doc['content'].lower()
        
        if any(term in title or term in content for term in ['diabetes', 'diabetic', 'insulin', 'blood sugar']):
            diabetes_content.append({
                'title': doc['title'],
                'section': doc['section'],
                'content': doc['content'][:200] + '...',
                'url': doc['url']
            })
    
    return diabetes_content

diabetes_articles = find_diabetes_content()

print(f"Found {len(diabetes_articles)} diabetes-related chunks")
print("\nDiabetes Treatment Content:")

treatment_content = [doc for doc in diabetes_articles if 'treatment' in doc['section']]
print(f"Treatment sections: {len(treatment_content)}")

for doc in treatment_content[:5]:
    print(f"\n• {doc['title']} ({doc['section']})")
    print(f"  Content: {doc['content']}")
# Out:
# Found 682 diabetes-related chunks
#
# Diabetes Treatment Content:
# Treatment sections: 140
#
# • Abdominal aortic aneurysm repair - open - discharge (treatment)
#   Content: Treatment options include:
#
# • Eat a heart-healthy diet.
# • Get regular exercise.
# • Stop smoking (if you smoke).
# • Take the medicines your health care provider has prescribed as directed. These may incl...
#
# • Acanthosis nigricans (treatment)
#   Content: Treatment options include:
#
# • Blood tests to check blood sugar level or insulin level
# • Endoscopy
# • X-rays...
#
# • Acromegaly (treatment)
#   Content: Treatment options include:
#
# • Blood glucose
# • Growth hormone
# • Insulin-like growth factor 1 (IGF-1)
# • Prolactin
# • Spine x-ray
# • MRI of the brain, including the pituitary gland
# • Echocardiogram
# • Colon...
#
# • Adrenal glands (treatment)
#   Content: Treatment options include:
#
# • Addison disease, also called adrenal insufficiency -- an autoimmune disorder that causes the adrenal glands to not produce enough hormones
# • Congenital adrenal hyperplasi...
#
# • Aging changes in skin (treatment)
#   Content: Treatment options include:
#
# • Blood vessel diseases, such asatherosclerosis
# • Diabetes
# • Heart disease
# • Liver disease
# • Nutritional deficiencies
# • Obesity
# • Reactions to medicines
# • Stress...

# %% [markdown]
# ## Finding specific diabetes articles

# %%
def find_primary_diabetes_articles():
    """Find articles where diabetes is the main topic"""
    
    primary_diabetes = []
    
    for doc in medical_documents_clean:
        title = doc['title'].lower()
        
        # Look for articles where diabetes is the main subject
        if any(term in title for term in ['diabetes', 'diabetic']):
            primary_diabetes.append({
                'title': doc['title'],
                'section': doc['section'],
                'content': doc['content'][:300] + '...',
                'url': doc['url']
            })
    
    return primary_diabetes

primary_diabetes_articles = find_primary_diabetes_articles()

print(f"Found {len(primary_diabetes_articles)} articles specifically about diabetes")

from collections import defaultdict
grouped = defaultdict(list)

for doc in primary_diabetes_articles:
    grouped[doc['title']].append(doc['section'])

print(f"\nPrimary Diabetes Articles:")
for title, sections in list(grouped.items())[:10]:
    print(f"\n• {title}")
    print(f"  Sections: {', '.join(sections)}")

print(f"\nDiabetes Treatment Sections:")
treatment_sections = [doc for doc in primary_diabetes_articles if 'treatment' in doc['section']]

for doc in treatment_sections[:5]:
    print(f"\n• {doc['title']} - {doc['section']}")
    print(f"  {doc['content']}")
# Out:
# Found 176 articles specifically about diabetes
#
# Primary Diabetes Articles:
#
# • Central diabetes insipidus
#   Sections: overview, symptoms, diagnosis, treatment
#
# • Cranial mononeuropathy III - diabetic type
#   Sections: overview, symptoms, causes, treatment, complications
#
# • Diabetes
#   Sections: overview, symptoms, causes, diagnosis, treatment, complications
#
# • Diabetes â resources
#   Sections: overview, treatment, prevention, complications
#
# • Diabetes - foot ulcers
#   Sections: overview, symptoms, causes, diagnosis, treatment
#
# • Diabetes - insulin therapy
#   Sections: causes, treatment
#
# • Diabetes - keeping active
#   Sections: overview, symptoms, causes, complications
#
# • Diabetes - preventing heart attack and stroke
#   Sections: causes, treatment, complications
#
# • Diabetes - taking care of your feet
#   Sections: causes, treatment, complications
#
# • Diabetes - when you are sick
#   Sections: overview, symptoms, causes, treatment
#
# Diabetes Treatment Sections:
#
# • Central diabetes insipidus - treatment
#   Treatment options include:
#
# • Blood sodiumandosmolarity
# • Desmopressin (DDAVP) challenge
# • MRI of the head
# • Urinalysis
# • Urine concentrationand osmolarity
# • Urine output...
#
# • Cranial mononeuropathy III - diabetic type - treatment
#   Treatment options include:
#
# • Blood tests
# • Tests to look at blood vessels in the brain (cerebral angiogram, CT angiogram,MR angiogram)
# • MRIorCT scan of the brain
# • Spinal tap (lumbar puncture)...
#
# • Diabetes - treatment
#   Treatment options include:
#
# • Fasting blood glucose level. Diabetes is diagnosed if the fasting glucose level is 126 mg/dL (7.0 mmol/L) or higher on two different tests, when the person is in their usual state of health. Levels from 100 mg/dL to 125 mg/dL (5.6 mmol/L to 7.0 mmol/L) are called impair...
#
# • Diabetes â resources - treatment
#   Treatment options include:
#
# • National Eye Institute --www.nei.nih.gov/learn-about-eye-health/eye-conditions-and-diseases/diabetic-retinopathy
# • American Academy of Ophthalmology --www.aao.org/eye-health/diseases/what-is-diabetic-retinopathy...
#
# • Diabetes - foot ulcers - treatment
#   Treatment options include:
#
# • The skin surrounding the wound is cleaned and disinfected.
# • The wound is probed with a metal instrument to see how deep it is and to see if there is any foreign material or object in the ulcer.
# • The provider cuts away the dead tissue, then washes out the ulcer.
# • Afte...

# %% [markdown]
# ## Checking DynamoDB content

# %%
def check_dynamodb_diabetes_content():
    """Check what diabetes content is actually in DynamoDB"""
    
    dynamodb = boto3.resource('dynamodb')
    table = dynamodb.Table('MedicalEmbeddings')

    response = table.scan(
        FilterExpression='contains(title, :diabetes)',
        ExpressionAttributeValues={':diabetes': 'Diabetes'}
    )
    
    items = response['Items']
    
    print(f"Found {len(items)} diabetes items in DynamoDB")

    treatment_items = [item for item in items if item.get('section') == 'treatment']
    
    print(f"Diabetes treatment items: {len(treatment_items)}")
    
    for item in treatment_items[:5]:
        print(f"\n• {item.get('title')} - {item.get('section')}")
        print(f"  Content: {item.get('content', '')[:200]}...")
        print(f"  Chunk ID: {item.get('chunk_id')}")

check_dynamodb_diabetes_content()
# Out:
# Found 2 diabetes items in DynamoDB
# Diabetes treatment items: 0

# %% [markdown]
# ## Uploading missing dynamodb content

# %%
def upload_missing_diabetes_content():
    """Upload diabetes-specific content that was missed"""
    
    print("Finding diabetes content to upload...")
    
    diabetes_content = []
    for doc in medical_documents_clean:
        title = doc['title'].lower()
        if 'diabetes' in title:
            diabetes_content.append(doc)
    
    print(f"Found {len(diabetes_content)} diabetes articles to upload")
    
    diabetes_embeddings = []
    for doc in diabetes_content:
        for emb in embeddings_data:
            if emb['chunk_id'] == doc['chunk_id']:
                diabetes_embeddings.append(emb)
                break
    
    print(f"Found {len(diabetes_embeddings)} diabetes embeddings to upload")

    dynamodb = boto3.resource('dynamodb')
    table = dynamodb.Table('MedicalEmbeddings')
    
    uploaded = 0
    
    for emb in diabetes_embeddings:
        try:
            embedding_list = [Decimal(str(float(x))) for x in emb['embedding']]
            
            item = {
                'chunk_id': emb['chunk_id'],
                'doc_id': emb['doc_id'],
                'section': emb['section'],
                'title': emb['title'],
                'content': emb['content'][:4000],
                'url': emb['url'],
                'embedding': embedding_list
            }
            
            table.put_item(Item=item)
            uploaded += 1
            
            if uploaded % 10 == 0:
                print(f" Uploaded {uploaded} diabetes items...")
                
        except Exception as e:
            print(f" Error uploading {emb['chunk_id']}: {str(e)}")
    
    print(f" Successfully uploaded {uploaded} diabetes items!")

upload_missing_diabetes_content()
# Out:
# Finding diabetes content to upload...
# Found 149 diabetes articles to upload
# Found 149 diabetes embeddings to upload
#  Uploaded 10 diabetes items...
#  Uploaded 20 diabetes items...
#  Uploaded 30 diabetes items...
#  Uploaded 40 diabetes items...
#  Uploaded 50 diabetes items...
#  Uploaded 60 diabetes items...
#  Uploaded 70 diabetes items...
#  Uploaded 80 diabetes items...
#  Uploaded 90 diabetes items...
#  Uploaded 100 diabetes items...
#  Uploaded 110 diabetes items...
#  Uploaded 120 diabetes items...
#  Uploaded 130 diabetes items...
#  Uploaded 140 diabetes items...
#  Successfully uploaded 149 diabetes items!

# %% [markdown]
# ## Verifying the diabetes upload

# %%
def verify_diabetes_upload():
    """Check if diabetes treatment content is now in DynamoDB"""
    
    dynamodb = boto3.resource('dynamodb')
    table = dynamodb.Table('MedicalEmbeddings')
    
    response = table.scan(
        FilterExpression='contains(title, :diabetes) AND #section = :treatment',
        ExpressionAttributeNames={'#section': 'section'},
        ExpressionAttributeValues={
            ':diabetes': 'Diabetes',
            ':treatment': 'treatment'
        }
    )
    
    items = response['Items']
    
    print(f"Found {len(items)} diabetes treatment items in DynamoDB")
    
    for item in items:
        print(f"\n• Title: {item.get('title')}")
        print(f"  Section: {item.get('section')}")
        print(f"  Chunk ID: {item.get('chunk_id')}")
        print(f"  Content preview: {item.get('content', '')[:150]}...")

    response2 = table.scan(
        FilterExpression='contains(title, :diabetes)',
        ExpressionAttributeValues={':diabetes': 'Diabetes'}
    )
    
    print(f"\nTotal diabetes items in DynamoDB: {len(response2['Items'])}")
    
    # Show titles
    titles = set()
    for item in response2['Items']:
        titles.add(item.get('title'))
    
    print(f"\nDiabetes article titles:")
    for title in sorted(titles):
        print(f"  • {title}")

verify_diabetes_upload()
# Out:
# Found 0 diabetes treatment items in DynamoDB
#
# Total diabetes items in DynamoDB: 2
#
# Diabetes article titles:
#   • Diabetes and nerve damage
#   • Diabetes eye care

# %% [markdown]
# ## Debugging upload issue

# %%
def debug_upload_issue():
    """Debugging why diabetes content isn't uploading properly"""
    
    print("Debugging upload issue...")
    
    diabetes_treatment = None
    
    for doc in medical_documents_clean:
        if doc['title'].lower() == 'diabetes' and doc['section'] == 'treatment':
            diabetes_treatment = doc
            break
    
    if diabetes_treatment:
        print(f"Found 'Diabetes - treatment' in local data:")
        print(f"   Title: {diabetes_treatment['title']}")
        print(f"   Section: {diabetes_treatment['section']}")
        print(f"   Chunk ID: {diabetes_treatment['chunk_id']}")
        print(f"   Content: {diabetes_treatment['content'][:200]}...")

        try:
            embedding_item = None
            for emb in embeddings_data:
                if emb['chunk_id'] == diabetes_treatment['chunk_id']:
                    embedding_item = emb
                    break
            
            if embedding_item:
                print(f"Found corresponding embedding")
                
                # Try manual upload
                dynamodb = boto3.resource('dynamodb')
                table = dynamodb.Table('MedicalEmbeddings')
                
                embedding_list = [Decimal(str(float(x))) for x in embedding_item['embedding']]
                
                item = {
                    'chunk_id': embedding_item['chunk_id'],
                    'doc_id': embedding_item['doc_id'],
                    'section': embedding_item['section'],
                    'title': embedding_item['title'],
                    'content': embedding_item['content'],
                    'url': embedding_item['url'],
                    'embedding': embedding_list
                }
                
                table.put_item(Item=item)
                print(f"Successfully uploaded diabetes treatment item!")
                
            else:
                print(f"No corresponding embedding found")
        
        except Exception as e:
            print(f"Upload error: {str(e)}")
    
    else:
        print(f"'Diabetes - treatment' not found in local data")
        
        diabetes_titles = set()
        for doc in medical_documents_clean:
            if 'diabetes' in doc['title'].lower():
                diabetes_titles.add(f"{doc['title']} - {doc['section']}")
        
        print(f"\nAvailable diabetes content:")
        for title in sorted(diabetes_titles):
            print(f"   • {title}")

debug_upload_issue()
# Out:
# Debugging upload issue...
# Found 'Diabetes - treatment' in local data:
#    Title: Diabetes
#    Section: treatment
#    Chunk ID: diabetes_treatment
#    Content: Treatment options include:
#
# • Fasting blood glucose level. Diabetes is diagnosed if the fasting glucose level is 126 mg/dL (7.0 mmol/L) or higher on two different tests, when the person is in their us...
# Found corresponding embedding
# Successfully uploaded diabetes treatment item!

# %% [markdown]
# ## Debug issue

# %%
def comprehensive_diabetes_debug():
    """
    Comprehensive debugging to find and upload all diabetes-related content
    """
    print("=== COMPREHENSIVE DIABETES DEBUG ===\n")
    
    diabetes_content = []
    
    for doc in medical_documents_clean:
        if 'diabetes' in doc['title'].lower():
            diabetes_content.append({
                'title': doc['title'],
                'section': doc['section'], 
                'chunk_id': doc['chunk_id'],
                'content': doc['content'][:150] + "...",
                'url': doc.get('url', 'N/A')
            })
    
    print(f"Found {len(diabetes_content)} diabetes-related chunks in local data:")
    for i, content in enumerate(diabetes_content, 1):
        print(f"{i:2d}. {content['title']} - {content['section']}")
        print(f"     Chunk ID: {content['chunk_id']}")
        print(f"     Content: {content['content']}")
        print(f"     URL: {content['url']}\n")
    
    print("=== CHECKING DYNAMODB CONTENT ===")
    
    try:
        dynamodb = boto3.resource('dynamodb')
        table = dynamodb.Table('MedicalEmbeddings')

        response = table.scan(
            FilterExpression=Attr('title').contains('diabetes') | Attr('title').contains('Diabetes'),
            ProjectionExpression='chunk_id, title, #section',
            ExpressionAttributeNames={'#section': 'section'}
        )
        
        db_diabetes = response['Items']
        print(f"Found {len(db_diabetes)} diabetes items in DynamoDB:")
        
        for item in db_diabetes:
            print(f"   • {item['title']} - {item['section']} (ID: {item['chunk_id']})")
            
    except Exception as e:
        print(f"DynamoDB check failed: {str(e)}")
    
    print("\n=== UPLOADING MISSING DIABETES CONTENT ===")
    
    uploaded_count = 0
    
    for doc in medical_documents_clean:
        if 'diabetes' in doc['title'].lower():
            try:
                embedding_item = None
                for emb in embeddings_data:
                    if emb['chunk_id'] == doc['chunk_id']:
                        embedding_item = emb
                        break
                
                if embedding_item:
                    embedding_list = [Decimal(str(float(x))) for x in embedding_item['embedding']]
                    
                    item = {
                        'chunk_id': embedding_item['chunk_id'],
                        'doc_id': embedding_item['doc_id'],
                        'section': embedding_item['section'],
                        'title': embedding_item['title'],
                        'content': embedding_item['content'],
                        'url': embedding_item['url'],
                        'embedding': embedding_list
                    }

                    table.put_item(Item=item)
                    print(f"Uploaded: {item['title']} - {item['section']}")
                    uploaded_count += 1
                    
                else:
                    print(f"No embedding found for: {doc['title']} - {doc['section']}")
                    
            except Exception as e:
                print(f"Upload failed for {doc['title']} - {doc['section']}: {str(e)}")
    
    print(f"\nSuccessfully uploaded {uploaded_count} diabetes items!")
    
    return diabetes_content

def test_lambda_search_locally():
    """
    Testing the same search logic locally to debug
    """
    print("\n=== TESTING SEARCH LOGIC LOCALLY ===")
    
    query = "diabetes treatment"
    query_lower = query.lower()
    
    dynamodb = boto3.resource('dynamodb')
    table = dynamodb.Table('MedicalEmbeddings')
    
    response = table.scan(
        ProjectionExpression='chunk_id, title, #section, content, #url',
        ExpressionAttributeNames={
            '#url': 'url',
            '#section': 'section'
        },
        Limit=3000
    )
    items = response['Items']
    
    print(f"Scanned {len(items)} total items from DynamoDB")
    
    scored_items = []
    
    for item in items:
        content = item.get('content', '').lower()
        title = item.get('title', '').lower()
        section = item.get('section', '').lower()

        score = 0

        if 'diabetes' in title and 'treatment' in section:
            score += 100
        elif 'diabetes' in title:
            if 'treatment' in query.lower():
                if 'treatment' in section:
                    score += 80
                elif 'treatment' in content:
                    score += 60
            else:
                score += 40
        elif 'diabetes' in content and 'treatment' in section:
            diabetes_count = content.count('diabetes')
            score += 30 + (diabetes_count * 5)
        elif 'diabetes' in content and 'treatment' in query.lower():
            score += 10

        if score >= 10:
            scored_items.append({
                'score': score,
                'title': item.get('title', ''),
                'section': item.get('section', ''),
                'content': item.get('content', '')[:200] + "...",
                'url': item.get('url', ''),
                'exact_match': score >= 80
            })
    
    scored_items.sort(key=lambda x: x['score'], reverse=True)
    
    print(f"\nFound {len(scored_items)} relevant items:")
    for i, item in enumerate(scored_items[:10], 1):
        print(f"{i:2d}. Score: {item['score']:3d} | {item['title']} - {item['section']}")
        print(f"     Content: {item['content']}")
        print()
    
    return scored_items

diabetes_debug_results = comprehensive_diabetes_debug()

local_search_results = test_lambda_search_locally()
# Out:
# === COMPREHENSIVE DIABETES DEBUG ===
#
# Found 149 diabetes-related chunks in local data:
#  1. Central diabetes insipidus - overview
#      Chunk ID: central_diabetes_insipidus_overview
#      Content: Central diabetes insipidus is a rare condition that involves extreme thirst and excessive urination....
#      URL: https://medlineplus.gov/ency/article/000460.htm
#
#  2. Central diabetes insipidus - symptoms
#      Chunk ID: central_diabetes_insipidus_symptoms
#      Content: Symptoms of this condition include:
#
# • Increased urine production
# • Excessive thirst
# • Confusion and changes in alertness due to dehydration and highe...
#      URL: https://medlineplus.gov/ency/article/000460.htm
#
#  3. Central diabetes insipidus - diagnosis
#      Chunk ID: central_diabetes_insipidus_diagnosis
#      Content: Diagnosis may involve:
#
# • Blood sodiumandosmolarity
# • Desmopressin (DDAVP) challenge
# • MRI of the head
# • Urinalysis
# • Urine concentrationand osmolarit...
#      URL: https://medlineplus.gov/ency/article/000460.htm
#
#  4. Central diabetes insipidus - treatment
#      Chunk ID: central_diabetes_insipidus_treatment
#      Content: Treatment options include:
#
# • Blood sodiumandosmolarity
# • Desmopressin (DDAVP) challenge
# • MRI of the head
# • Urinalysis
# • Urine concentrationand osmol...
#      URL: https://medlineplus.gov/ency/article/000460.htm
#
#  5. Diabetes - overview
#      Chunk ID: diabetes_overview
#      Content: Diabetes is a long-term (chronic) disease in which the body cannot regulate the amount of sugar in the blood....
#      URL: https://medlineplus.gov/ency/article/001214.htm
#
#  6. Diabetes - symptoms
#      Chunk ID: diabetes_symptoms
#      Content: Symptoms of this condition include:
#
# • Blurry vision
# • Excess thirst
# • Fatigue
# • Frequent urination
# • Hunger
# • Weight loss...
#      URL: https://medlineplus.gov/ency/article/001214.htm
#
#  7. Diabetes - causes
#      Chunk ID: diabetes_causes
#      Content: Causes of this condition include:
#
# • Their pancreas does not make enough insulin
# • Their cells do not respond to insulin normally (also called insulin...
#      URL: https://medlineplus.gov/ency/article/001214.htm
#
#  8. Diabetes - diagnosis
#      Chunk ID: diabetes_diagnosis
#      Content: Diagnosis may involve:
#
# • Fasting blood glucose level. Diabetes is diagnosed if the fasting glucose level is 126 mg/dL (7.0 mmol/L) or higher on two d...
#      URL: https://medlineplus.gov/ency/article/001214.htm
#
#  9. Diabetes - treatment
#      Chunk ID: diabetes_treatment
#      Content: Treatment options include:
#
# • Fasting blood glucose level. Diabetes is diagnosed if the fasting glucose level is 126 mg/dL (7.0 mmol/L) or higher on t...
#      URL: https://medlineplus.gov/ency/article/001214.htm
#
# 10. Diabetes - complications
#      Chunk ID: diabetes_complications
#      Content: Possible complications include:
#
# • Eye problems, including trouble seeing (especially at night), light sensitivity, cataracts, and blindness
# • Sores a...
#      URL: https://medlineplus.gov/ency/article/001214.htm
#
# 11. Diabetes â resources - overview
#      Chunk ID: diabetes_â_resources_overview
#      Content: The following sites provide further information ondiabetes:...
#      URL: https://medlineplus.gov/ency/article/002179.htm
#
# 12. Diabetes â resources - treatment
#      Chunk ID: diabetes_â_resources_treatment
#      Content: Treatment options include:
#
# • National Eye Institute --www.nei.nih.gov/learn-about-eye-health/eye-conditions-and-diseases/diabetic-retinopathy
# • Ameri...
#      URL: https://medlineplus.gov/ency/article/002179.htm
#
# 13. Diabetes â resources - prevention
#      Chunk ID: diabetes_â_resources_prevention
#      Content: Prevention measures include:
#
# • National Eye Institute --www.nei.nih.gov/learn-about-eye-health/eye-conditions-and-diseases/diabetic-retinopathy
# • Ame...
#      URL: https://medlineplus.gov/ency/article/002179.htm
#
# 14. Diabetes â resources - complications
#      Chunk ID: diabetes_â_resources_complications
#      Content: Possible complications include:
#
# • National Eye Institute --www.nei.nih.gov/learn-about-eye-health/eye-conditions-and-diseases/diabetic-retinopathy
# • ...
#      URL: https://medlineplus.gov/ency/article/002179.htm
#
# 15. Diabetes - foot ulcers - overview
#      Chunk ID: diabetes_-_foot_ulcers_overview
#      Content: If you have diabetes, you have an increased chance of developing foot sores, or ulcers, also called diabetic ulcers....
#      URL: https://medlineplus.gov/ency/patientinstructions/000077.htm
#
# 16. Diabetes - foot ulcers - symptoms
#      Chunk ID: diabetes_-_foot_ulcers_symptoms
#      Content: Symptoms of this condition include:
#
# • Redness, increased warmth, or swelling around the wound
# • Extra drainage
# • Pus
# • Odor
# • Fever orchills
# • Increa...
#      URL: https://medlineplus.gov/ency/patientinstructions/000077.htm
#
# 17. Diabetes - foot ulcers - causes
#      Chunk ID: diabetes_-_foot_ulcers_causes
#      Content: Causes of this condition include:
#
# • Wear shoes made of canvas, leather, or suede. Don't wear shoes made of plastic or other materials that don't allo...
#      URL: https://medlineplus.gov/ency/patientinstructions/000077.htm
#
# 18. Diabetes - foot ulcers - diagnosis
#      Chunk ID: diabetes_-_foot_ulcers_diagnosis
#      Content: Diagnosis may involve:
#
# • Redness, increased warmth, or swelling around the wound
# • Extra drainage
# • Pus
# • Odor
# • Fever orchills
# • Increased pain
# • In...
#      URL: https://medlineplus.gov/ency/patientinstructions/000077.htm
#
# 19. Diabetes - foot ulcers - treatment
#      Chunk ID: diabetes_-_foot_ulcers_treatment
#      Content: Treatment options include:
#
# • The skin surrounding the wound is cleaned and disinfected.
# • The wound is probed with a metal instrument to see how deep...
#      URL: https://medlineplus.gov/ency/patientinstructions/000077.htm
#
# 20. Diabetes - insulin therapy - causes
#      Chunk ID: diabetes_-_insulin_therapy_causes
#      Content: Causes of this condition include:
#
# • In people withtype 1 diabetesthe pancreas produces little to no insulin.
# • In people withtype 2 diabetesthe fat, ...
#      URL: https://medlineplus.gov/ency/patientinstructions/000965.htm
#
# 21. Diabetes - insulin therapy - treatment
#      Chunk ID: diabetes_-_insulin_therapy_treatment
#      Content: Treatment options include:
#
# • Basal dose- provides a steady amount of insulin delivered all day and night. This helps maintain blood glucose levels by...
#      URL: https://medlineplus.gov/ency/patientinstructions/000965.htm
#
# 22. Diabetes - keeping active - overview
#      Chunk ID: diabetes_-_keeping_active_overview
#      Content: If you havediabetes, you may think that only vigorous exercise is helpful. But this is not true. Increasing your daily activity by any amount can help...
#      URL: https://medlineplus.gov/ency/patientinstructions/000084.htm
#
# 23. Diabetes - keeping active - symptoms
#      Chunk ID: diabetes_-_keeping_active_symptoms
#      Content: Symptoms of this condition include:
#
# • Also havehigh blood pressure
# • Also havehigh cholesterol
# • Smoke
# • Have a history ofheart diseasein your family...
#      URL: https://medlineplus.gov/ency/patientinstructions/000084.htm
#
# 24. Diabetes - keeping active - causes
#      Chunk ID: diabetes_-_keeping_active_causes
#      Content: Causes of this condition include:
#
# • Also havehigh blood pressure
# • Also havehigh cholesterol
# • Smoke
# • Have a history ofheart diseasein your family...
#      URL: https://medlineplus.gov/ency/patientinstructions/000084.htm
#
# 25. Diabetes - keeping active - complications
#      Chunk ID: diabetes_-_keeping_active_complications
#      Content: Possible complications include:
#
# • Also havehigh blood pressure
# • Also havehigh cholesterol
# • Smoke
# • Have a history ofheart diseasein your family...
#      URL: https://medlineplus.gov/ency/patientinstructions/000084.htm
#
# 26. Diabetes - preventing heart attack and stroke - causes
#      Chunk ID: diabetes_-_preventing_heart_attack_and_stroke_causes
#      Content: Causes of this condition include:
#
# • Follow your meal plan and watch how much you eat. This can help you lose weight if you are overweight or obese.
# •...
#      URL: https://medlineplus.gov/ency/patientinstructions/000080.htm
#
# 27. Diabetes - preventing heart attack and stroke - treatment
#      Chunk ID: diabetes_-_preventing_heart_attack_and_stroke_treatment
#      Content: Standards of Care in Diabetes-2024.Diabetes Care. 2024;47(Suppl 1):S179-S218. PMID: 38078592pubmed.ncbi.nlm.nih.gov/38078592/.Arnett DK, Blumenthal RS...
#      URL: https://medlineplus.gov/ency/patientinstructions/000080.htm
#
# 28. Diabetes - preventing heart attack and stroke - complications
#      Chunk ID: diabetes_-_preventing_heart_attack_and_stroke_complications
#      Content: Possible complications include:
#
# • Follow your meal plan and watch how much you eat. This can help you lose weight if you are overweight or obese.
# • D...
#      URL: https://medlineplus.gov/ency/patientinstructions/000080.htm
#
# 29. Diabetes - taking care of your feet - causes
#      Chunk ID: diabetes_-_taking_care_of_your_feet_causes
#      Content: Causes of this condition include:
#
# • Check the temperature of the water with your hand or elbow first.
# • Gently dry your feet, especially between the ...
#      URL: https://medlineplus.gov/ency/patientinstructions/000081.htm
#
# 30. Diabetes - taking care of your feet - treatment
#      Chunk ID: diabetes_-_taking_care_of_your_feet_treatment
#      Content: Treatment options include:
#
# • Dry and cracked skin
# • Blisters or sores
# • Bruises or cuts
# • Redness, warmth, or tenderness (often absent because of ner...
#      URL: https://medlineplus.gov/ency/patientinstructions/000081.htm
#
# 31. Diabetes - taking care of your feet - complications
#      Chunk ID: diabetes_-_taking_care_of_your_feet_complications
#      Content: Possible complications include:
#
# • Redness, increased warmth, or swelling
# • Sores or cracks
# • Tingling or burning feeling
# • Pain...
#      URL: https://medlineplus.gov/ency/patientinstructions/000081.htm
#
# 32. Diabetes - when you are sick - overview
#      Chunk ID: diabetes_-_when_you_are_sick_overview
#      Content: Waiting too long to get medical care when you are sick can lead to getting much sicker. When you have diabetes, a delay in getting care can be life th...
#      URL: https://medlineplus.gov/ency/patientinstructions/000079.htm
#
# 33. Diabetes - when you are sick - symptoms
#      Chunk ID: diabetes_-_when_you_are_sick_symptoms
#      Content: Symptoms of this condition include:
#
# • High blood sugarthat will not come down with treatment
# • Nausea and vomiting
# • Low blood sugarthat will not ris...
#      URL: https://medlineplus.gov/ency/patientinstructions/000079.htm
#
# 34. Diabetes - when you are sick - causes
#      Chunk ID: diabetes_-_when_you_are_sick_causes
#      Content: Causes of this condition include:
#
# • Blood sugar higher than 240 mg/dL (13.3 mmol/L) for more than 1 day
# • Moderate-to-large ketones with your urine t...
#      URL: https://medlineplus.gov/ency/patientinstructions/000079.htm
#
# 35. Diabetes - when you are sick - treatment
#      Chunk ID: diabetes_-_when_you_are_sick_treatment
#      Content: Treatment options include:
#
# • High blood sugarthat will not come down with treatment
# • Nausea and vomiting
# • Low blood sugarthat will not rise after y...
#      URL: https://medlineplus.gov/ency/patientinstructions/000079.htm
#
# 36. Diabetes and alcohol - overview
#      Chunk ID: diabetes_and_alcohol_overview
#      Content: If you havediabetes, you may wonder if it's safe to drink alcohol. While many people with diabetes can drink alcohol in moderation, it's important to ...
#      URL: https://medlineplus.gov/ency/patientinstructions/000968.htm
#
# 37. Diabetes and alcohol - symptoms
#      Chunk ID: diabetes_and_alcohol_symptoms
#      Content: Symptoms of this condition include:
#
# • Double vision or blurry vision
# • Fast or pounding heartbeat
# • Feeling cranky or acting aggressive
# • Feeling ner...
#      URL: https://medlineplus.gov/ency/patientinstructions/000968.htm
#
# 38. Diabetes and alcohol - causes
#      Chunk ID: diabetes_and_alcohol_causes
#      Content: Causes of this condition include:
#
# • Alcoholic drinks such as beer and sweetened mixed drinks are high in carbohydrates, which can raise blood sugar l...
#      URL: https://medlineplus.gov/ency/patientinstructions/000968.htm
#
# 39. Diabetes and alcohol - treatment
#      Chunk ID: diabetes_and_alcohol_treatment
#      Content: Treatment options include:
#
# • Alcoholic drinks such as beer and sweetened mixed drinks are high in carbohydrates, which can raise blood sugar levels.
# ...
#      URL: https://medlineplus.gov/ency/patientinstructions/000968.htm
#
# 40. Diabetes and alcohol - prevention
#      Chunk ID: diabetes_and_alcohol_prevention
#      Content: Prevention measures include:
#
# • Before you start drinking
# • While you are drinking
# • A few hours after drinking
# • Up to the next 24 hours...
#      URL: https://medlineplus.gov/ency/patientinstructions/000968.htm
#
# 41. Diabetes and alcohol - complications
#      Chunk ID: diabetes_and_alcohol_complications
#      Content: Possible complications include:
#
# • Alcoholic drinks such as beer and sweetened mixed drinks are high in carbohydrates, which can raise blood sugar lev...
#      URL: https://medlineplus.gov/ency/patientinstructions/000968.htm
#
# 42. Diabetes and eye disease - overview
#      Chunk ID: diabetes_and_eye_disease_overview
#      Content: Diabetes can harm the eyes. It can damage the small blood vessels in the retina, the back part of your eye. This condition is called diabetic retinopa...
#      URL: https://medlineplus.gov/ency/article/001212.htm
#
# 43. Diabetes and eye disease - symptoms
#      Chunk ID: diabetes_and_eye_disease_symptoms
#      Content: Symptoms of this condition include:
#
# • Blurred vision and slow vision loss over time
# • Floaters
# • Shadows or missing areas of vision
# • Trouble seeing ...
#      URL: https://medlineplus.gov/ency/article/001212.htm
#
# 44. Diabetes and eye disease - causes
#      Chunk ID: diabetes_and_eye_disease_causes
#      Content: Causes of this condition include:
#
# • You have had diabetes for a long time.
# • Your blood sugar (glucose) has been poorly controlled.
# • You also smoke ...
#      URL: https://medlineplus.gov/ency/article/001212.htm
#
# 45. Diabetes and eye disease - diagnosis
#      Chunk ID: diabetes_and_eye_disease_diagnosis
#      Content: Diagnosis may involve:
#
# • Measuring the fluid pressure inside your eyes (tonometry)
# • Checking the structures inside your eyes (slit lamp exam)
# • Chec...
#      URL: https://medlineplus.gov/ency/article/001212.htm
#
# 46. Diabetes and eye disease - treatment
#      Chunk ID: diabetes_and_eye_disease_treatment
#      Content: Treatment options include:
#
# • Laser eye surgery creates small burns in the retina where there are abnormal blood vessels. This process is called photo...
#      URL: https://medlineplus.gov/ency/article/001212.htm
#
# 47. Diabetes and eye disease - complications
#      Chunk ID: diabetes_and_eye_disease_complications
#      Content: Possible complications include:
#
# • Cataract-- Cloudiness of the eye lens.
# • Glaucoma-- Increased pressure in the eye that can lead to blindness.
# • Mac...
#      URL: https://medlineplus.gov/ency/article/001212.htm
#
# 48. Diabetes and kidney disease - overview
#      Chunk ID: diabetes_and_kidney_disease_overview
#      Content: Kidney disease or kidney damage often occurs over time in people with diabetes. This type of kidney disease is called diabetic nephropathy....
#      URL: https://medlineplus.gov/ency/article/000494.htm
#
# 49. Diabetes and kidney disease - symptoms
#      Chunk ID: diabetes_and_kidney_disease_symptoms
#      Content: Symptoms of this condition include:
#
# • Fatigue most of the time
# • General ill feeling
# • Headache
# • Irregular heartbeat
# • Nausea and vomiting
# • Poor ap...
#      URL: https://medlineplus.gov/ency/article/000494.htm
#
# 50. Diabetes and kidney disease - causes
#      Chunk ID: diabetes_and_kidney_disease_causes
#      Content: Causes of this condition include:
#
# • Blood urea nitrogen (BUN)
# • Serum creatinine
# • Estimated glomerular filtration rate (eGFR)...
#      URL: https://medlineplus.gov/ency/article/000494.htm
#
# 51. Diabetes and kidney disease - diagnosis
#      Chunk ID: diabetes_and_kidney_disease_diagnosis
#      Content: Diagnosis may involve:
#
# • Blood urea nitrogen (BUN)
# • Serum creatinine
# • Estimated glomerular filtration rate (eGFR)...
#      URL: https://medlineplus.gov/ency/article/000494.htm
#
# 52. Diabetes and kidney disease - treatment
#      Chunk ID: diabetes_and_kidney_disease_treatment
#      Content: Treatment options include:
#
# • Too much albumin in the urine is often a sign of kidney damage.
# • This test is also called amicroalbuminuriatest because...
#      URL: https://medlineplus.gov/ency/article/000494.htm
#
# 53. Diabetes and kidney disease - complications
#      Chunk ID: diabetes_and_kidney_disease_complications
#      Content: Possible complications include:
#
# • Too much albumin in the urine is often a sign of kidney damage.
# • This test is also called amicroalbuminuriatest be...
#      URL: https://medlineplus.gov/ency/article/000494.htm
#
# 54. Diabetes and nerve damage - overview
#      Chunk ID: diabetes_and_nerve_damage_overview
#      Content: Nerve damage that occurs in people with diabetes is called diabetic neuropathy. This condition is a complication ofdiabetes....
#      URL: https://medlineplus.gov/ency/article/000693.htm
#
# 55. Diabetes and nerve damage - symptoms
#      Chunk ID: diabetes_and_nerve_damage_symptoms
#      Content: Symptoms of this condition include:
#
# • Not notice when you step on something sharp
# • Not know that you have a blister or small cut
# • Not notice when y...
#      URL: https://medlineplus.gov/ency/article/000693.htm
#
# 56. Diabetes and nerve damage - causes
#      Chunk ID: diabetes_and_nerve_damage_causes
#      Content: Causes of this condition include:
#
# • Not notice when you step on something sharp
# • Not know that you have a blister or small cut
# • Not notice when you...
#      URL: https://medlineplus.gov/ency/article/000693.htm
#
# 57. Diabetes and nerve damage - diagnosis
#      Chunk ID: diabetes_and_nerve_damage_diagnosis
#      Content: Diagnosis may involve:
#
# • Electromyogram(EMG), a recording of electrical activity in muscles
# • Nerve conduction velocity tests (NCV), a recording of t...
#      URL: https://medlineplus.gov/ency/article/000693.htm
#
# 58. Diabetes and nerve damage - treatment
#      Chunk ID: diabetes_and_nerve_damage_treatment
#      Content: Treatment options include:
#
# • No reflexes or weak reflexes in the ankle
# • Loss of feeling in the feet (this is checked with a brush-like instrument ca...
#      URL: https://medlineplus.gov/ency/article/000693.htm
#
# 59. Diabetes and nerve damage - complications
#      Chunk ID: diabetes_and_nerve_damage_complications
#      Content: Possible complications include:
#
# • Feeling full after eating only a small amount of food
# • Heartburnand bloating
# • Nausea, constipation, or diarrhea
# •...
#      URL: https://medlineplus.gov/ency/article/000693.htm
#
# 60. Diabetes eye care - causes
#      Chunk ID: diabetes_eye_care_causes
#      Content: Causes of this condition include:
#
# • Blood pressure less than 130/80 is a goal for people with diabetes.
# • Have your blood pressure checked often and ...
#      URL: https://medlineplus.gov/ency/patientinstructions/000078.htm
#
# 61. Diabetes eye care - treatment
#      Chunk ID: diabetes_eye_care_treatment
#      Content: Treatment options include:
#
# • Use felt tip pens to label medicine bottles, so you can read them easily.
# • Use rubber bands or clips to tell medicine b...
#      URL: https://medlineplus.gov/ency/patientinstructions/000078.htm
#
# 62. Diabetes eye care - prevention
#      Chunk ID: diabetes_eye_care_prevention
#      Content: Prevention measures include:
#
# • Weight lifting and other exercises that make you strain
# • High-impact exercise, such as football or hockey...
#      URL: https://medlineplus.gov/ency/patientinstructions/000078.htm
#
# 63. Diabetes eye care - complications
#      Chunk ID: diabetes_eye_care_complications
#      Content: Possible complications include:
#
# • Weight lifting and other exercises that make you strain
# • High-impact exercise, such as football or hockey...
#      URL: https://medlineplus.gov/ency/patientinstructions/000078.htm
#
# 64. Diabetes insipidus - overview
#      Chunk ID: diabetes_insipidus_overview
#      Content: Diabetes insipidus (DI) is an uncommon condition in which the kidneys are unable to prevent the excretion of water....
#      URL: https://medlineplus.gov/ency/article/000377.htm
#
# 65. Diabetes insipidus - symptoms
#      Chunk ID: diabetes_insipidus_symptoms
#      Content: Symptoms of this condition include:
#
# • Excessive thirstthat may be intense or uncontrollable, usually with the need to drink large amounts of water or...
#      URL: https://medlineplus.gov/ency/article/000377.htm
#
# 66. Diabetes insipidus - causes
#      Chunk ID: diabetes_insipidus_causes
#      Content: Causes of this condition include:
#
# • Certain medicines, such as lithium
# • Genetic problems
# • High level of calcium in the body (hypercalcemia)
# • Kidne...
#      URL: https://medlineplus.gov/ency/article/000377.htm
#
# 67. Diabetes insipidus - diagnosis
#      Chunk ID: diabetes_insipidus_diagnosis
#      Content: Diagnosis may involve:
#
# • Blood sodiumandosmolality
# • Desmopressin (DDAVP) challenge
# • MRI of the head
# • Serum co-peptin level
# • Urinalysis
# • Urine co...
#      URL: https://medlineplus.gov/ency/article/000377.htm
#
# 68. Diabetes insipidus - treatment
#      Chunk ID: diabetes_insipidus_treatment
#      Content: Treatment options include:
#
# • Certain medicines, such as lithium
# • Genetic problems
# • High level of calcium in the body (hypercalcemia)
# • Kidney disea...
#      URL: https://medlineplus.gov/ency/article/000377.htm
#
# 69. Diabetes insipidus - complications
#      Chunk ID: diabetes_insipidus_complications
#      Content: Possible complications include:
#
# • Certain medicines, such as lithium
# • Genetic problems
# • High level of calcium in the body (hypercalcemia)
# • Kidney ...
#      URL: https://medlineplus.gov/ency/article/000377.htm
#
# 70. Diabetes myths and facts - overview
#      Chunk ID: diabetes_myths_and_facts_overview
#      Content: Diabetesis a long-term (chronic) disease in which the body cannot regulate the amount of glucose (sugar) in the blood. Diabetes is a complicated disea...
#      URL: https://medlineplus.gov/ency/patientinstructions/000964.htm
#
# 71. Diabetes myths and facts - causes
#      Chunk ID: diabetes_myths_and_facts_causes
#      Content: Fact:It is true that excess weight increases your chance of having diabetes. However, many people who are overweight or obese never develop diabetes. ...
#      URL: https://medlineplus.gov/ency/patientinstructions/000964.htm
#
# 72. Diabetes myths and facts - treatment
#      Chunk ID: diabetes_myths_and_facts_treatment
#      Content: Fact:Some people with type 2 diabetes are able to control their blood sugar without medicine by losing weight, eating a healthy diet, and getting regu...
#      URL: https://medlineplus.gov/ency/patientinstructions/000964.htm
#
# 73. Diabetes tests and checkups - diagnosis
#      Chunk ID: diabetes_tests_and_checkups_diagnosis
#      Content: Diagnosis may involve:
#
# • Ask your health care provider questions
# • Learn more about your diabetes and what you can do to keep your blood sugar in you...
#      URL: https://medlineplus.gov/ency/patientinstructions/000082.htm
#
# 74. Diabetes tests and checkups - treatment
#      Chunk ID: diabetes_tests_and_checkups_treatment
#      Content: Treatment options include:
#
# • Ask your health care provider questions
# • Learn more about your diabetes and what you can do to keep your blood sugar in...
#      URL: https://medlineplus.gov/ency/patientinstructions/000082.htm
#
# 75. Diabetes type 2 - meal planning - overview
#      Chunk ID: diabetes_type_2_-_meal_planning_overview
#      Content: When you havetype 2 diabetes, taking time to plan your meals goes a long way toward controlling your blood sugar (glucose) and weight....
#      URL: https://medlineplus.gov/ency/article/007429.htm
#
# 76. Diabetes type 2 - meal planning - treatment
#      Chunk ID: diabetes_type_2_-_meal_planning_treatment
#      Content: Treatment options include:
#
# • Whole grains are unprocessed and have the entire grain kernel. Examples are whole-wheat flour, oatmeal, whole cornmeal, ...
#      URL: https://medlineplus.gov/ency/article/007429.htm
#
# 77. Diabetes type 2 - meal planning - prevention
#      Chunk ID: diabetes_type_2_-_meal_planning_prevention
#      Content: Prevention measures include:
#
# • Ask for extra spoons and forks and split your dessert with others.
# • Eat sweets that are sugar-free.
# • Always ask for ...
#      URL: https://medlineplus.gov/ency/article/007429.htm
#
# 78. Gestational diabetes - overview
#      Chunk ID: gestational_diabetes_overview
#      Content: Gestational diabetes is high blood sugar (glucose) that starts or is first diagnosed during pregnancy....
#      URL: https://medlineplus.gov/ency/article/000896.htm
#
# 79. Gestational diabetes - symptoms
#      Chunk ID: gestational_diabetes_symptoms
#      Content: Symptoms of this condition include:
#
# • Blurred vision
# • Fatigue
# • Frequent infections, including those of the bladder, vagina, and skin
# • Increased th...
#      URL: https://medlineplus.gov/ency/article/000896.htm
#
# 80. Gestational diabetes - causes
#      Chunk ID: gestational_diabetes_causes
#      Content: Causes of this condition include:
#
# • Birth injury (trauma) because of the baby's large size
# • Delivery byC-section...
#      URL: https://medlineplus.gov/ency/article/000896.htm
#
# 81. Gestational diabetes - diagnosis
#      Chunk ID: gestational_diabetes_diagnosis
#      Content: Diagnosis may involve:
#
# • Blurred vision
# • Fatigue
# • Frequent infections, including those of the bladder, vagina, and skin
# • Increased thirst
# • Increa...
#      URL: https://medlineplus.gov/ency/article/000896.htm
#
# 82. Gestational diabetes - treatment
#      Chunk ID: gestational_diabetes_treatment
#      Content: Treatment options include:
#
# • A machine that hears and displays your baby's heartbeat (electronic fetal monitor) is placed on your abdomen.
# • Your pro...
#      URL: https://medlineplus.gov/ency/article/000896.htm
#
# 83. Gestational diabetes - complications
#      Chunk ID: gestational_diabetes_complications
#      Content: Possible complications include:
#
# • Birth injury (trauma) because of the baby's large size
# • Delivery byC-section...
#      URL: https://medlineplus.gov/ency/article/000896.htm
#
# 84. Gestational diabetes - self-care - causes
#      Chunk ID: gestational_diabetes_-_self-care_causes
#      Content: Causes of this condition include:
#
# • Stillbirth
# • Very small baby (fetal growth restriction) or very large baby (macrosomia)
# • Difficult labor orcesar...
#      URL: https://medlineplus.gov/ency/patientinstructions/000598.htm
#
# 85. Gestational diabetes - self-care - treatment
#      Chunk ID: gestational_diabetes_-_self-care_treatment
#      Content: Treatment options include:
#
# • Stillbirth
# • Very small baby (fetal growth restriction) or very large baby (macrosomia)
# • Difficult labor orcesarean bir...
#      URL: https://medlineplus.gov/ency/patientinstructions/000598.htm
#
# 86. Gestational diabetes - self-care - complications
#      Chunk ID: gestational_diabetes_-_self-care_complications
#      Content: Possible complications include:
#
# • Stillbirth
# • Very small baby (fetal growth restriction) or very large baby (macrosomia)
# • Difficult labor orcesarea...
#      URL: https://medlineplus.gov/ency/patientinstructions/000598.htm
#
# 87. Gestational diabetes diet - causes
#      Chunk ID: gestational_diabetes_diet_causes
#      Content: Causes of this condition include:
#
# • 1 slice bread
# • 1 ounce (28 grams) ready-to-eat cereal
# • 1/2 cup (105 grams) cooked rice or pasta
# • 1 English muf...
#      URL: https://medlineplus.gov/ency/article/007430.htm
#
# 88. Gestational diabetes diet - treatment
#      Chunk ID: gestational_diabetes_diet_treatment
#      Content: Treatment options include:
#
# • Plenty of whole fruits and vegetables
# • Moderate amounts of lean proteins and healthy fats
# • Moderate amounts of whole g...
#      URL: https://medlineplus.gov/ency/article/007430.htm
#
# 89. Gestational diabetes diet - prevention
#      Chunk ID: gestational_diabetes_diet_prevention
#      Content: Prevention measures include:
#
# • 1 slice bread
# • 1 ounce (28 grams) ready-to-eat cereal
# • 1/2 cup (105 grams) cooked rice or pasta
# • 1 English muffin...
#      URL: https://medlineplus.gov/ency/article/007430.htm
#
# 90. Immunizations for people with diabetes - overview
#      Chunk ID: immunizations_for_people_with_diabetes_overview
#      Content: Immunizations(vaccines or vaccinations) help protect you from some diseases. When you havediabetes, you're more likely to get severe infections becaus...
#      URL: https://medlineplus.gov/ency/patientinstructions/000331.htm
#
# 91. Long-term complications of diabetes - causes
#      Chunk ID: long-term_complications_of_diabetes_causes
#      Content: Causes of this condition include:
#
# • You could haveeye problems. You could have trouble seeing, particularly at night. Light could bother your eyes. Y...
#      URL: https://medlineplus.gov/ency/patientinstructions/000327.htm
#
# 92. Long-term complications of diabetes - diagnosis
#      Chunk ID: long-term_complications_of_diabetes_diagnosis
#      Content: Diagnosis may involve:
#
# • Make sure your kidneys are working well (every year)
# • Make sure your cholesterol and triglyceride levels are healthy (every...
#      URL: https://medlineplus.gov/ency/patientinstructions/000327.htm
#
# 93. Long-term complications of diabetes - treatment
#      Chunk ID: long-term_complications_of_diabetes_treatment
#      Content: Treatment options include:
#
# • You may use a device called a glucose meter totest your blood sugar. Your provider will let you know if you need to chec...
#      URL: https://medlineplus.gov/ency/patientinstructions/000327.htm
#
# 94. Long-term complications of diabetes - complications
#      Chunk ID: long-term_complications_of_diabetes_complications
#      Content: Possible complications include:
#
# • You could haveeye problems. You could have trouble seeing, particularly at night. Light could bother your eyes. You...
#      URL: https://medlineplus.gov/ency/patientinstructions/000327.htm
#
# 95. Nephrogenic diabetes insipidus - overview
#      Chunk ID: nephrogenic_diabetes_insipidus_overview
#      Content: Nephrogenic diabetes insipidus (NDI) is a disorder in which a defect in the small tubes (tubules) in the kidneys causes a person to pass a large amoun...
#      URL: https://medlineplus.gov/ency/article/000511.htm
#
# 96. Nephrogenic diabetes insipidus - symptoms
#      Chunk ID: nephrogenic_diabetes_insipidus_symptoms
#      Content: Symptoms of this condition include:
#
# • Dry mucous membranes
# • Dry skin
# • Sunken appearance to eyes
# • Sunken fontanelles (soft spot) in infants
# • Chang...
#      URL: https://medlineplus.gov/ency/article/000511.htm
#
# 97. Nephrogenic diabetes insipidus - causes
#      Chunk ID: nephrogenic_diabetes_insipidus_causes
#      Content: Causes of this condition include:
#
# • Blockage in the urinary tract
# • High blood calcium levels
# • Low blood potassium levels
# • Use of certain medicines...
#      URL: https://medlineplus.gov/ency/article/000511.htm
#
# 98. Nephrogenic diabetes insipidus - diagnosis
#      Chunk ID: nephrogenic_diabetes_insipidus_diagnosis
#      Content: Diagnosis may involve:
#
# • High serum osmolality
# • High urine output, regardless of how much fluid you drink
# • Kidneys do not concentrate urine when yo...
#      URL: https://medlineplus.gov/ency/article/000511.htm
#
# 99. Nephrogenic diabetes insipidus - treatment
#      Chunk ID: nephrogenic_diabetes_insipidus_treatment
#      Content: Treatment options include:
#
# • High serum osmolality
# • High urine output, regardless of how much fluid you drink
# • Kidneys do not concentrate urine whe...
#      URL: https://medlineplus.gov/ency/article/000511.htm
#
# 100. Nerve damage from diabetes - self-care - symptoms
#      Chunk ID: nerve_damage_from_diabetes_-_self-care_symptoms
#      Content: Symptoms of this condition include:
#
# • Feeling full after eating only a small amount of food
# • Heartburn and bloating
# • Nausea, constipation, or diarr...
#      URL: https://medlineplus.gov/ency/patientinstructions/000326.htm
#
# 101. Nerve damage from diabetes - self-care - causes
#      Chunk ID: nerve_damage_from_diabetes_-_self-care_causes
#      Content: Causes of this condition include:
#
# • Feet and legs
# • Hands and arms
# • Digestive tract
# • Heart
# • Bladder...
#      URL: https://medlineplus.gov/ency/patientinstructions/000326.htm
#
# 102. Nerve damage from diabetes - self-care - treatment
#      Chunk ID: nerve_damage_from_diabetes_-_self-care_treatment
#      Content: Treatment options include:
#
# • Medicines may help reduce painful symptoms in the feet, legs, and arms. They usually do not bring back loss of feeling. ...
#      URL: https://medlineplus.gov/ency/patientinstructions/000326.htm
#
# 103. Nerve damage from diabetes - self-care - complications
#      Chunk ID: nerve_damage_from_diabetes_-_self-care_complications
#      Content: Possible complications include:
#
# • Feeling full after eating only a small amount of food
# • Heartburn and bloating
# • Nausea, constipation, or diarrhea
# ...
#      URL: https://medlineplus.gov/ency/patientinstructions/000326.htm
#
# 104. Prediabetes - overview
#      Chunk ID: prediabetes_overview
#      Content: Prediabetes occurs when the level of sugar (glucose) in your blood is too high, but not high enough to be calleddiabetes....
#      URL: https://medlineplus.gov/ency/patientinstructions/000778.htm
#
# 105. Prediabetes - symptoms
#      Chunk ID: prediabetes_symptoms
#      Content: Symptoms of this condition include:
#
# • A previous diabetes test showing diabetes risk
# • A parent, sibling, or child with a history of diabetes
# • Inact...
#      URL: https://medlineplus.gov/ency/patientinstructions/000778.htm
#
# 106. Prediabetes - causes
#      Chunk ID: prediabetes_causes
#      Content: Causes of this condition include:
#
# • Eat healthy foods.This includes whole grains, lean proteins, low-fat dairy, and plenty of vegetables. Watchportio...
#      URL: https://medlineplus.gov/ency/patientinstructions/000778.htm
#
# 107. Prediabetes - diagnosis
#      Chunk ID: prediabetes_diagnosis
#      Content: Diagnosis may involve:
#
# • Fasting blood glucose of 100 to 125 mg/dL (called impaired fasting glucose)
# • Blood glucose of 140 to 199 mg/dL 2 hours afte...
#      URL: https://medlineplus.gov/ency/patientinstructions/000778.htm
#
# 108. Prediabetes - treatment
#      Chunk ID: prediabetes_treatment
#      Content: Treatment options include:
#
# • Fasting blood glucose of 100 to 125 mg/dL (called impaired fasting glucose)
# • Blood glucose of 140 to 199 mg/dL 2 hours ...
#      URL: https://medlineplus.gov/ency/patientinstructions/000778.htm
#
# 109. Prediabetes - complications
#      Chunk ID: prediabetes_complications
#      Content: Possible complications include:
#
# • Eat healthy foods.This includes whole grains, lean proteins, low-fat dairy, and plenty of vegetables. Watchportion ...
#      URL: https://medlineplus.gov/ency/patientinstructions/000778.htm
#
# 110. Preparing for surgery when you have diabetes - causes
#      Chunk ID: preparing_for_surgery_when_you_have_diabetes_causes
#      Content: Causes of this condition include:
#
# • Have trouble eating
# • Are vomiting
# • Are stressed after surgery
# • Are less active than usual
# • Have pain or disco...
#      URL: https://medlineplus.gov/ency/patientinstructions/000702.htm
#
# 111. Preparing for surgery when you have diabetes - treatment
#      Chunk ID: preparing_for_surgery_when_you_have_diabetes_treatment
#      Content: Treatment options include:
#
# • Infection after surgery (especially at the site of the surgery)
# • Healing more slowly
# • Fluid,electrolyte, and kidney pr...
#      URL: https://medlineplus.gov/ency/patientinstructions/000702.htm
#
# 112. Preparing for surgery when you have diabetes - complications
#      Chunk ID: preparing_for_surgery_when_you_have_diabetes_complications
#      Content: Possible complications include:
#
# • Infection after surgery (especially at the site of the surgery)
# • Healing more slowly
# • Fluid,electrolyte, and kidn...
#      URL: https://medlineplus.gov/ency/patientinstructions/000702.htm
#
# 113. Snacking when you have diabetes - overview
#      Chunk ID: snacking_when_you_have_diabetes_overview
#      Content: When you havediabetes, you need to control your blood sugar (glucose). Insulin or diabetes medicines, as well asexercisein general, help lower your bl...
#      URL: https://medlineplus.gov/ency/patientinstructions/000322.htm
#
# 114. Snacking when you have diabetes - treatment
#      Chunk ID: snacking_when_you_have_diabetes_treatment
#      Content: Treatment options include:
#
# • Your body quickly turns carbohydrates into a sugar called glucose. This raises your blood sugar level. Carbohydrates are...
#      URL: https://medlineplus.gov/ency/patientinstructions/000322.htm
#
# 115. Type 1 diabetes - overview
#      Chunk ID: type_1_diabetes_overview
#      Content: Type 1 diabetes is a lifelong (chronic) disease in which there is a high level of sugar (glucose) in the blood....
#      URL: https://medlineplus.gov/ency/article/000305.htm
#
# 116. Type 1 diabetes - symptoms
#      Chunk ID: type_1_diabetes_symptoms
#      Content: Symptoms of this condition include:
#
# • Being very thirsty
# • Feeling hungry
# • Feeling tired all the time
# • Having blurry eyesight
# • Feeling numbness or...
#      URL: https://medlineplus.gov/ency/article/000305.htm
#
# 117. Type 1 diabetes - causes
#      Chunk ID: type_1_diabetes_causes
#      Content: Causes of this condition include:
#
# • Check the skin and bones on your feet and legs.
# • Check if your feet are getting numb (diabetic nerve disease).
# •...
#      URL: https://medlineplus.gov/ency/article/000305.htm
#
# 118. Type 1 diabetes - diagnosis
#      Chunk ID: type_1_diabetes_diagnosis
#      Content: Diagnosis may involve:
#
# • Fasting blood glucoselevel -- Diabetes is diagnosed if it is 126 mg/dL (7 mmol/L) or higher two different times.
# • Random (n...
#      URL: https://medlineplus.gov/ency/article/000305.htm
#
# 119. Type 1 diabetes - treatment
#      Chunk ID: type_1_diabetes_treatment
#      Content: Treatment options include:
#
# • Check the skin and bones on your feet and legs.
# • Check if your feet are getting numb (diabetic nerve disease).
# • Have y...
#      URL: https://medlineplus.gov/ency/article/000305.htm
#
# 120. Type 1 diabetes - prevention
#      Chunk ID: type_1_diabetes_prevention
#      Content: Prevention measures include:
#
# • Eye disease
# • Kidney disease
# • Peripheral nerve damage
# • Heart disease and stroke...
#      URL: https://medlineplus.gov/ency/article/000305.htm
#
# 121. Type 1 diabetes - complications
#      Chunk ID: type_1_diabetes_complications
#      Content: Possible complications include:
#
# • Check the skin and bones on your feet and legs.
# • Check if your feet are getting numb (diabetic nerve disease).
# • H...
#      URL: https://medlineplus.gov/ency/article/000305.htm
#
# 122. Type 1 diabetes - self-care - symptoms
#      Chunk ID: type_1_diabetes_-_self-care_symptoms
#      Content: Symptoms of this condition include:
#
# • High blood glucose readings
# • High glucose in the urine
# • Being very thirsty
# • Urinating more often (including ...
#      URL: https://medlineplus.gov/ency/patientinstructions/000990.htm
#
# 123. Type 1 diabetes - self-care - causes
#      Chunk ID: type_1_diabetes_-_self-care_causes
#      Content: Causes of this condition include:
#
# • High blood glucose readings
# • High glucose in the urine
# • Being very thirsty
# • Urinating more often (including ur...
#      URL: https://medlineplus.gov/ency/patientinstructions/000990.htm
#
# 124. Type 1 diabetes - self-care - diagnosis
#      Chunk ID: type_1_diabetes_-_self-care_diagnosis
#      Content: Diagnosis may involve:
#
# • Check yourfeetevery day.
# • Look for signs of reactions to insulin or any firm areas at your insulin injection sites.
# • Have ...
#      URL: https://medlineplus.gov/ency/patientinstructions/000990.htm
#
# 125. Type 1 diabetes - self-care - treatment
#      Chunk ID: type_1_diabetes_-_self-care_treatment
#      Content: Treatment options include:
#
# • High blood glucose readings
# • High glucose in the urine
# • Being very thirsty
# • Urinating more often (including urinating...
#      URL: https://medlineplus.gov/ency/patientinstructions/000990.htm
#
# 126. Type 1 diabetes - self-care - complications
#      Chunk ID: type_1_diabetes_-_self-care_complications
#      Content: Possible complications include:
#
# • Check yourfeetevery day.
# • Look for signs of reactions to insulin or any firm areas at your insulin injection sites...
#      URL: https://medlineplus.gov/ency/patientinstructions/000990.htm
#
# 127. Type 2 diabetes - overview
#      Chunk ID: type_2_diabetes_overview
#      Content: Type 2 diabetes is a lifelong (chronic) disease in which there is a high level of sugar (glucose) in the blood. Type 2 diabetes is the most common for...
#      URL: https://medlineplus.gov/ency/article/000313.htm
#
# 128. Type 2 diabetes - symptoms
#      Chunk ID: type_2_diabetes_symptoms
#      Content: Symptoms of this condition include:
#
# • Bladder, kidney, skin, or other infections that are more frequent or heal slowly
# • Fatigue
# • Hunger
# • Increased...
#      URL: https://medlineplus.gov/ency/article/000313.htm
#
# 129. Type 2 diabetes - causes
#      Chunk ID: type_2_diabetes_causes
#      Content: Causes of this condition include:
#
# • Bladder, kidney, skin, or other infections that are more frequent or heal slowly
# • Fatigue
# • Hunger
# • Increased t...
#      URL: https://medlineplus.gov/ency/article/000313.htm
#
# 130. Type 2 diabetes - diagnosis
#      Chunk ID: type_2_diabetes_diagnosis
#      Content: Diagnosis may involve:
#
# • Fasting blood glucoselevel -- Diabetes is diagnosed if it is 126 mg/dL (7.0 mmol/L) or higher two different times when the p...
#      URL: https://medlineplus.gov/ency/article/000313.htm
#
# 131. Type 2 diabetes - treatment
#      Chunk ID: type_2_diabetes_treatment
#      Content: Treatment options include:
#
# • Fasting blood glucoselevel -- Diabetes is diagnosed if it is 126 mg/dL (7.0 mmol/L) or higher two different times when t...
#      URL: https://medlineplus.gov/ency/article/000313.htm
#
# 132. Type 2 diabetes - prevention
#      Chunk ID: type_2_diabetes_prevention
#      Content: Prevention measures include:
#
# • Check the skin, nerves, and joints of your feet and legs.
# • Check if your feet are getting numb (diabetic nerve diseas...
#      URL: https://medlineplus.gov/ency/article/000313.htm
#
# 133. Type 2 diabetes - complications
#      Chunk ID: type_2_diabetes_complications
#      Content: Possible complications include:
#
# • Check the skin, nerves, and joints of your feet and legs.
# • Check if your feet are getting numb (diabetic nerve dis...
#      URL: https://medlineplus.gov/ency/article/000313.htm
#
# 134. Type 2 diabetes - oral medicines - symptoms
#      Chunk ID: type_2_diabetes_-_oral_medicines_symptoms
#      Content: Symptoms of this condition include:
#
# • Low blood sugar
# • Nausea and flatulence
# • Diarrhea
# • Skin rash
# • Weight gain
# • Stomach upset
# • Headache
# • Const...
#      URL: https://medlineplus.gov/ency/patientinstructions/000989.htm
#
# 135. Type 2 diabetes - oral medicines - causes
#      Chunk ID: type_2_diabetes_-_oral_medicines_causes
#      Content: Causes of this condition include:
#
# • Immediate-release: Taken 2 to 3 times a day
# • Sustained-release: Taken as a single dose every day, most often wit...
#      URL: https://medlineplus.gov/ency/patientinstructions/000989.htm
#
# 136. Type 2 diabetes - oral medicines - treatment
#      Chunk ID: type_2_diabetes_-_oral_medicines_treatment
#      Content: Treatment options include:
#
# • Help the body produce insulin
# • Increase the sensitivity of body tissues to insulin
# • Help with carbohydrate digestion a...
#      URL: https://medlineplus.gov/ency/patientinstructions/000989.htm
#
# 137. Type 2 diabetes - oral medicines - prevention
#      Chunk ID: type_2_diabetes_-_oral_medicines_prevention
#      Content: Prevention measures include:
#
# • Are useful if you don't eat meals at regular times
# • Can be taken anytime between 30 minutes before a meal up to mealt...
#      URL: https://medlineplus.gov/ency/patientinstructions/000989.htm
#
# 138. Type 2 diabetes - oral medicines - complications
#      Chunk ID: type_2_diabetes_-_oral_medicines_complications
#      Content: Possible complications include:
#
# • Muscle pain
# • Stuffy nose
# • Sore throat
# • Respiratory infection
# • Headache
# • Stomach ache...
#      URL: https://medlineplus.gov/ency/patientinstructions/000989.htm
#
# 139. Type 2 diabetes - self-care - symptoms
#      Chunk ID: type_2_diabetes_-_self-care_symptoms
#      Content: Symptoms of this condition include:
#
# • Hunger
# • Thirst
# • Urinating a lot, getting up more often than usual at night to urinate
# • Blurry vision
# • More ...
#      URL: https://medlineplus.gov/ency/patientinstructions/000328.htm
#
# 140. Type 2 diabetes - self-care - causes
#      Chunk ID: type_2_diabetes_-_self-care_causes
#      Content: Causes of this condition include:
#
# • Check and care for your feetevery day.
# • Make sure you're wearing the right kind of socks and shoes. Check your s...
#      URL: https://medlineplus.gov/ency/patientinstructions/000328.htm
#
# 141. Type 2 diabetes - self-care - diagnosis
#      Chunk ID: type_2_diabetes_-_self-care_diagnosis
#      Content: Diagnosis may involve:
#
# • Kidneys are working well (every year)
# • Cholesterol and triglyceride levels are healthy (every year)
# • A1C level is in a goo...
#      URL: https://medlineplus.gov/ency/patientinstructions/000328.htm
#
# 142. Type 2 diabetes - self-care - treatment
#      Chunk ID: type_2_diabetes_-_self-care_treatment
#      Content: Treatment options include:
#
# • An ACE inhibitor or another medicine called an ARB for high blood pressure or kidney problems.
# • A medicine called a sta...
#      URL: https://medlineplus.gov/ency/patientinstructions/000328.htm
#
# 143. Type 2 diabetes - self-care - complications
#      Chunk ID: type_2_diabetes_-_self-care_complications
#      Content: Possible complications include:
#
# • Checking your blood sugarat home
# • Keeping ahealthy diet
# • Beingphysically active...
#      URL: https://medlineplus.gov/ency/patientinstructions/000328.htm
#
# 144. Type 2 diabetes - what to ask your doctor - overview
#      Chunk ID: type_2_diabetes_-_what_to_ask_your_doctor_overview
#      Content: Type 2 diabetes, once diagnosed, is a lifelong disease that causes a high level of sugar (glucose) in your blood. It can damage your organs. It can al...
#      URL: https://medlineplus.gov/ency/patientinstructions/000217.htm
#
# 145. Type 2 diabetes - what to ask your doctor - symptoms
#      Chunk ID: type_2_diabetes_-_what_to_ask_your_doctor_symptoms
#      Content: Symptoms of this condition include:
#
# • What should I eat or drink?
# • How should I take my diabetes medicines?
# • How often should I check my blood suga...
#      URL: https://medlineplus.gov/ency/patientinstructions/000217.htm
#
# 146. Type 2 diabetes - what to ask your doctor - diagnosis
#      Chunk ID: type_2_diabetes_-_what_to_ask_your_doctor_diagnosis
#      Content: Diagnosis may involve:
#
# • What should I eat or drink?
# • How should I take my diabetes medicines?
# • How often should I check my blood sugar?
# • When sho...
#      URL: https://medlineplus.gov/ency/patientinstructions/000217.htm
#
# 147. Type 2 diabetes - what to ask your doctor - treatment
#      Chunk ID: type_2_diabetes_-_what_to_ask_your_doctor_treatment
#      Content: Treatment options include:
#
# • When should I take them?
# • What should I do if I miss a dose?
# • Are there any side effects?...
#      URL: https://medlineplus.gov/ency/patientinstructions/000217.htm
#
# 148. Type 2 diabetes - what to ask your doctor - prevention
#      Chunk ID: type_2_diabetes_-_what_to_ask_your_doctor_prevention
#      Content: Prevention measures include:
#
# • What foods increase my blood sugar the most?
# • What foods can help me with my weight loss goals?...
#      URL: https://medlineplus.gov/ency/patientinstructions/000217.htm
#
# 149. Type 2 diabetes - what to ask your doctor - complications
#      Chunk ID: type_2_diabetes_-_what_to_ask_your_doctor_complications
#      Content: Possible complications include:
#
# • Before I start, do I need to have my heart checked? My eyes? My feet?
# • What type of exercise program should I do? ...
#      URL: https://medlineplus.gov/ency/patientinstructions/000217.htm
#
# === CHECKING DYNAMODB CONTENT ===
# DynamoDB check failed: name 'Attr' is not defined
#
# === UPLOADING MISSING DIABETES CONTENT ===
# Uploaded: Central diabetes insipidus - overview
# Uploaded: Central diabetes insipidus - symptoms
# Uploaded: Central diabetes insipidus - diagnosis
# Uploaded: Central diabetes insipidus - treatment
# Uploaded: Diabetes - overview
# Uploaded: Diabetes - symptoms
# Uploaded: Diabetes - causes
# Uploaded: Diabetes - diagnosis
# Uploaded: Diabetes - treatment
# Uploaded: Diabetes - complications
# Uploaded: Diabetes â resources - overview
# Uploaded: Diabetes â resources - treatment
# Uploaded: Diabetes â resources - prevention
# Uploaded: Diabetes â resources - complications
# Uploaded: Diabetes - foot ulcers - overview
# Uploaded: Diabetes - foot ulcers - symptoms
# Uploaded: Diabetes - foot ulcers - causes
# Uploaded: Diabetes - foot ulcers - diagnosis
# Uploaded: Diabetes - foot ulcers - treatment
# Uploaded: Diabetes - insulin therapy - causes
# Uploaded: Diabetes - insulin therapy - treatment
# Uploaded: Diabetes - keeping active - overview
# Uploaded: Diabetes - keeping active - symptoms
# Uploaded: Diabetes - keeping active - causes
# Uploaded: Diabetes - keeping active - complications
# Uploaded: Diabetes - preventing heart attack and stroke - causes
# Uploaded: Diabetes - preventing heart attack and stroke - treatment
# Uploaded: Diabetes - preventing heart attack and stroke - complications
# Uploaded: Diabetes - taking care of your feet - causes
# Uploaded: Diabetes - taking care of your feet - treatment
# Uploaded: Diabetes - taking care of your feet - complications
# Uploaded: Diabetes - when you are sick - overview
# Uploaded: Diabetes - when you are sick - symptoms
# Uploaded: Diabetes - when you are sick - causes
# Uploaded: Diabetes - when you are sick - treatment
# Uploaded: Diabetes and alcohol - overview
# Uploaded: Diabetes and alcohol - symptoms
# Uploaded: Diabetes and alcohol - causes
# Uploaded: Diabetes and alcohol - treatment
# Uploaded: Diabetes and alcohol - prevention
# Uploaded: Diabetes and alcohol - complications
# Uploaded: Diabetes and eye disease - overview
# Uploaded: Diabetes and eye disease - symptoms
# Uploaded: Diabetes and eye disease - causes
# Uploaded: Diabetes and eye disease - diagnosis
# Uploaded: Diabetes and eye disease - treatment
# Uploaded: Diabetes and eye disease - complications
# Uploaded: Diabetes and kidney disease - overview
# Uploaded: Diabetes and kidney disease - symptoms
# Uploaded: Diabetes and kidney disease - causes
# Uploaded: Diabetes and kidney disease - diagnosis
# Uploaded: Diabetes and kidney disease - treatment
# Uploaded: Diabetes and kidney disease - complications
# Uploaded: Diabetes and nerve damage - overview
# Uploaded: Diabetes and nerve damage - symptoms
# Uploaded: Diabetes and nerve damage - causes
# Uploaded: Diabetes and nerve damage - diagnosis
# Uploaded: Diabetes and nerve damage - treatment
# Uploaded: Diabetes and nerve damage - complications
# Uploaded: Diabetes eye care - causes
# Uploaded: Diabetes eye care - treatment
# Uploaded: Diabetes eye care - prevention
# Uploaded: Diabetes eye care - complications
# Uploaded: Diabetes insipidus - overview
# Uploaded: Diabetes insipidus - symptoms
# Uploaded: Diabetes insipidus - causes
# Uploaded: Diabetes insipidus - diagnosis
# Uploaded: Diabetes insipidus - treatment
# Uploaded: Diabetes insipidus - complications
# Uploaded: Diabetes myths and facts - overview
# Uploaded: Diabetes myths and facts - causes
# Uploaded: Diabetes myths and facts - treatment
# Uploaded: Diabetes tests and checkups - diagnosis
# Uploaded: Diabetes tests and checkups - treatment
# Uploaded: Diabetes type 2 - meal planning - overview
# Uploaded: Diabetes type 2 - meal planning - treatment
# Uploaded: Diabetes type 2 - meal planning - prevention
# Uploaded: Gestational diabetes - overview
# Uploaded: Gestational diabetes - symptoms
# Uploaded: Gestational diabetes - causes
# Uploaded: Gestational diabetes - diagnosis
# Uploaded: Gestational diabetes - treatment
# Uploaded: Gestational diabetes - complications
# Uploaded: Gestational diabetes - self-care - causes
# Uploaded: Gestational diabetes - self-care - treatment
# Uploaded: Gestational diabetes - self-care - complications
# Uploaded: Gestational diabetes diet - causes
# Uploaded: Gestational diabetes diet - treatment
# Uploaded: Gestational diabetes diet - prevention
# Uploaded: Immunizations for people with diabetes - overview
# Uploaded: Long-term complications of diabetes - causes
# Uploaded: Long-term complications of diabetes - diagnosis
# Uploaded: Long-term complications of diabetes - treatment
# Uploaded: Long-term complications of diabetes - complications
# Uploaded: Nephrogenic diabetes insipidus - overview
# Uploaded: Nephrogenic diabetes insipidus - symptoms
# Uploaded: Nephrogenic diabetes insipidus - causes
# Uploaded: Nephrogenic diabetes insipidus - diagnosis
# Uploaded: Nephrogenic diabetes insipidus - treatment
# Uploaded: Nerve damage from diabetes - self-care - symptoms
# Uploaded: Nerve damage from diabetes - self-care - causes
# Uploaded: Nerve damage from diabetes - self-care - treatment
# Uploaded: Nerve damage from diabetes - self-care - complications
# Uploaded: Prediabetes - overview
# Uploaded: Prediabetes - symptoms
# Uploaded: Prediabetes - causes
# Uploaded: Prediabetes - diagnosis
# Uploaded: Prediabetes - treatment
# Uploaded: Prediabetes - complications
# Uploaded: Preparing for surgery when you have diabetes - causes
# Uploaded: Preparing for surgery when you have diabetes - treatment
# Uploaded: Preparing for surgery when you have diabetes - complications
# Uploaded: Snacking when you have diabetes - overview
# Uploaded: Snacking when you have diabetes - treatment
# Uploaded: Type 1 diabetes - overview
# Uploaded: Type 1 diabetes - symptoms
# Uploaded: Type 1 diabetes - causes
# Uploaded: Type 1 diabetes - diagnosis
# Uploaded: Type 1 diabetes - treatment
# Uploaded: Type 1 diabetes - prevention
# Uploaded: Type 1 diabetes - complications
# Uploaded: Type 1 diabetes - self-care - symptoms
# Uploaded: Type 1 diabetes - self-care - causes
# Uploaded: Type 1 diabetes - self-care - diagnosis
# Uploaded: Type 1 diabetes - self-care - treatment
# Uploaded: Type 1 diabetes - self-care - complications
# Uploaded: Type 2 diabetes - overview
# Uploaded: Type 2 diabetes - symptoms
# Uploaded: Type 2 diabetes - causes
# Uploaded: Type 2 diabetes - diagnosis
# Uploaded: Type 2 diabetes - treatment
# Uploaded: Type 2 diabetes - prevention
# Uploaded: Type 2 diabetes - complications
# Uploaded: Type 2 diabetes - oral medicines - symptoms
# Uploaded: Type 2 diabetes - oral medicines - causes
# Uploaded: Type 2 diabetes - oral medicines - treatment
# Uploaded: Type 2 diabetes - oral medicines - prevention
# Uploaded: Type 2 diabetes - oral medicines - complications
# Uploaded: Type 2 diabetes - self-care - symptoms
# Uploaded: Type 2 diabetes - self-care - causes
# Uploaded: Type 2 diabetes - self-care - diagnosis
# Uploaded: Type 2 diabetes - self-care - treatment
# Uploaded: Type 2 diabetes - self-care - complications
# Uploaded: Type 2 diabetes - what to ask your doctor - overview
# Uploaded: Type 2 diabetes - what to ask your doctor - symptoms
# Uploaded: Type 2 diabetes - what to ask your doctor - diagnosis
# Uploaded: Type 2 diabetes - what to ask your doctor - treatment
# Uploaded: Type 2 diabetes - what to ask your doctor - prevention
# Uploaded: Type 2 diabetes - what to ask your doctor - complications
#
# Successfully uploaded 149 diabetes items!
#
# === TESTING SEARCH LOGIC LOCALLY ===
# Scanned 202 total items from DynamoDB
#
# Found 2 relevant items:
#  1. Score:  35 | COPD and other health problems - treatment
#      Content: Treatment options include:
#
# • COPD usually develops in middle age. And people tend to have more health problems as they age.
# • COPD makes it hard to breathe, which can make it hard to get enough exerc...
#
#  2. Score:  10 | Health screenings for women age 65 and older - prevention
#      Content: Prevention measures include:
#
# • You have diabetes,heart disease,kidney problems, or are overweight or have certain other health conditions.
# • You have a first-degree relative with high blood pressure....

# %% [markdown]
# ## Lambda clear cache

# %%
import boto3
import json

def clear_lambda_cache():
    """
    Clear the QueryCache table to force fresh searches
    """
    
    print("=== CLEARING LAMBDA CACHE ===")
    
    try:
        dynamodb = boto3.resource('dynamodb')
        cache_table = dynamodb.Table('QueryCache')
        
        response = cache_table.scan()
        items = response['Items']
        
        print(f"Found {len(items)} cached queries:")
        
        for item in items:
            print(f"  • {item.get('query', 'Unknown query')}")
        
        deleted_count = 0
        
        for item in items:
            try:
                cache_table.delete_item(
                    Key={'query_hash': item['query_hash']}
                )
                deleted_count += 1
            except Exception as e:
                print(f"Failed to delete item: {str(e)}")
        
        print(f"\nSuccessfully cleared {deleted_count} cached items")
        print("Next Lambda request will use the new universal search algorithm!")
        
    except Exception as e:
        print(f"Failed to clear cache: {str(e)}")

def test_cache_clearing():
    """
    Test a query to see if cache was cleared
    """
    print("\n=== TESTING CACHE CLEARING ===")
    
    print("After clearing cache, your next Lambda test should:")
    print("1. Show 'cached': false")
    print("2. Show 'method': 'universal_medical_search'") 
    print("3. Return actual diabetes treatment content")
    print("4. Have much higher relevance scores (100+ for exact matches)")

clear_lambda_cache()
test_cache_clearing()
# Out:
# === CLEARING LAMBDA CACHE ===
# Found 3 cached queries:
#   • what are the causes of headache
#   • headache causes
#   • migraine treatment
#
# ✅ Successfully cleared 3 cached items
# Next Lambda request will use the new universal search algorithm!
#
# === TESTING CACHE CLEARING ===
# After clearing cache, your next Lambda test should:
# 1. Show 'cached': false
# 2. Show 'method': 'universal_medical_search'
# 3. Return actual diabetes treatment content
# 4. Have much higher relevance scores (100+ for exact matches)
